# %% [markdown]
# # Generating Music with Genetic Algorithms: From Melody Creation to MIDI and Music Sheet Visualization
#
# ### Description: In this notebook, we explore how Genetic Algorithms (GA) can be used to generate musical melodies. Starting with a basic scale and rhythmic structure, we evolved a melody through genetic processes, demonstrating the creative potential of AI. We then took the generated sequence and converted it into a MIDI file to hear the result, and visualized the melody in a music sheet format. This project showcases the intersection of AI and art, highlighting how algorithms can be used to generate original musical compositions.
#
# ### author: @jecs89
# ### Date: 14/11/2024
# ### Source: https://github.com/jecs89/LearningEveryDay
#
# ### Help by ChatGpt

# %% [markdown]
# # Genetic Algorithms
# ### Definition: https://en.wikipedia.org/wiki/Genetic_algorithm
#
# ### Representation
# <img src='https://www.researchgate.net/publication/349241302/figure/fig3/AS:990383379070978@1613137206590/Genetic-selection-method-using-genetic-algorithm.png'>

# %%
import random

# Define the scales (using numbers representing the pitch classes)
# C major scale: C, D, E, F, G, A, B
# D minor scale: D, E, F, G, A, Bb, C
scales = {
    'C_major': ['C', 'D', 'E', 'F', 'G', 'A', 'B'],
    'D_minor': ['D', 'E', 'F', 'G', 'A', 'Bb', 'C']
}

# Genetic Algorithm settings
population_size = 10  # Number of melodies in each generation
melody_length = 20     # Number of notes in each melody
generations = 20      # Number of generations

# Define mutation rate
mutation_rate = 0.1

# Chromosome Representation: Each chromosome is a list of note indices (in scale)
def generate_melody(scale):
    """Generate a random melody within the given scale"""
    return [random.choice(scale) for _ in range(melody_length)]

def fitness(melody, scale):
    """Fitness function: check if all notes are within the scale"""
    return sum([1 for note in melody if note in scale])

def selection(population, fitness_values):
    """Select the top half of the population based on fitness"""
    sorted_population = [x for _, x in sorted(zip(fitness_values, population), reverse=True)]
    return sorted_population[:len(population)//2]

def crossover(parent1, parent2):
    """Single point crossover"""
    crossover_point = random.randint(1, len(parent1)-1)
    child1 = parent1[:crossover_point] + parent2[crossover_point:]
    child2 = parent2[:crossover_point] + parent1[crossover_point:]
    return child1, child2

def mutation(melody, scale):
    """Random mutation: change one note in the melody"""
    if random.random() < mutation_rate:
        mutation_point = random.randint(0, len(melody)-1)
        melody[mutation_point] = random.choice(scale)
    return melody

# Main GA loop
def genetic_algorithm(scale_name):
    scale = scales[scale_name]
    population = [generate_melody(scale) for _ in range(population_size)]

    for generation in range(generations):
        print(f"Generation {generation+1}")
        
        # Evaluate fitness of the population
        fitness_values = [fitness(melody, scale) for melody in population]
        best_fitness = max(fitness_values)
        print(f"Best fitness in this generation: {best_fitness}")
        
        # Selection: Select top half based on fitness
        selected_population = selection(population, fitness_values)
        
        # Crossover: Create new population
        new_population = []
        while len(new_population) < population_size:
            parent1, parent2 = random.sample(selected_population, 2)
            child1, child2 = crossover(parent1, parent2)
            new_population.extend([child1, child2])
        
        # Mutation: Apply mutation to the new population
        population = [mutation(melody, scale) for melody in new_population]

        # Print the best melody from the current generation
        best_melody = population[fitness_values.index(best_fitness)]
        print(f"Best melody: {best_melody}")
    
    # Return the best melody from the last generation
    fitness_values = [fitness(melody, scale) for melody in population]
    best_melody = population[fitness_values.index(max(fitness_values))]
    return best_melody

# Running the Genetic Algorithm for C Major Scale
best_melody = genetic_algorithm('C_major')
print(f"Best Melody: {best_melody}")
# Out:
# Generation 1
# Best fitness in this generation: 20
# Best melody: ['E', 'D', 'F', 'G', 'C', 'B', 'G', 'F', 'B', 'D', 'G', 'F', 'E', 'A', 'D', 'G', 'E', 'G', 'A', 'F']
# Generation 2
# Best fitness in this generation: 20
# Best melody: ['E', 'D', 'F', 'G', 'F', 'A', 'C', 'G', 'G', 'D', 'G', 'F', 'E', 'A', 'D', 'G', 'E', 'G', 'A', 'F']
# Generation 3
# Best fitness in this generation: 20
# Best melody: ['E', 'D', 'F', 'G', 'F', 'A', 'C', 'G', 'G', 'D', 'G', 'F', 'E', 'A', 'D', 'G', 'E', 'G', 'A', 'F']
# Generation 4
# Best fitness in this generation: 20
# Best melody: ['E', 'D', 'F', 'G', 'F', 'A', 'D', 'G', 'G', 'D', 'G', 'F', 'E', 'A', 'D', 'G', 'E', 'G', 'A', 'F']
# Generation 5
# Best fitness in this generation: 20
# Best melody: ['D', 'F', 'E', 'B', 'F', 'A', 'C', 'G', 'G', 'D', 'G', 'F', 'E', 'A', 'D', 'G', 'E', 'G', 'A', 'F']
# Generation 6
# Best fitness in this generation: 20
# Best melody: ['E', 'F', 'F', 'B', 'F', 'A', 'C', 'G', 'G', 'D', 'G', 'F', 'E', 'A', 'D', 'G', 'E', 'G', 'A', 'F']
# Generation 7
# Best fitness in this generation: 20
# Best melody: ['E', 'F', 'F', 'G', 'A', 'A', 'C', 'G', 'G', 'D', 'G', 'F', 'E', 'A', 'D', 'G', 'E', 'G', 'A', 'F']
# Generation 8
# Best fitness in this generation: 20
# Best melody: ['E', 'F', 'F', 'G', 'F', 'A', 'C', 'G', 'G', 'D', 'G', 'F', 'E', 'A', 'D', 'G', 'E', 'G', 'A', 'F']
# Generation 9
# Best fitness in this generation: 20
# Best melody: ['E', 'F', 'F', 'G', 'F', 'A', 'C', 'G', 'G', 'D', 'G', 'F', 'E', 'A', 'D', 'G', 'E', 'G', 'A', 'F']
# Generation 10
# Best fitness in this generation: 20
# Best melody: ['E', 'F', 'F', 'G', 'F', 'A', 'C', 'G', 'G', 'D', 'G', 'F', 'E', 'A', 'D', 'G', 'E', 'G', 'A', 'F']
# Generation 11
# Best fitness in this generation: 20
# Best melody: ['E', 'F', 'F', 'G', 'F', 'A', 'C', 'G', 'G', 'D', 'G', 'F', 'E', 'A', 'D', 'G', 'E', 'G', 'A', 'F']
# Generation 12
# Best fitness in this generation: 20
# Best melody: ['E', 'F', 'F', 'G', 'F', 'A', 'C', 'G', 'G', 'D', 'G', 'F', 'E', 'A', 'D', 'G', 'E', 'G', 'A', 'F']
# Generation 13
# Best fitness in this generation: 20
# Best melody: ['E', 'F', 'F', 'G', 'F', 'A', 'C', 'G', 'G', 'D', 'G', 'F', 'E', 'A', 'D', 'G', 'E', 'G', 'A', 'F']
# Generation 14
# Best fitness in this generation: 20
# Best melody: ['E', 'F', 'F', 'G', 'F', 'A', 'C', 'G', 'G', 'D', 'G', 'F', 'E', 'A', 'D', 'G', 'E', 'G', 'A', 'F']
# Generation 15
# Best fitness in this generation: 20
# Best melody: ['E', 'F', 'F', 'G', 'F', 'A', 'C', 'G', 'G', 'D', 'G', 'F', 'E', 'A', 'D', 'G', 'E', 'G', 'A', 'F']
# Generation 16
# Best fitness in this generation: 20
# Best melody: ['E', 'F', 'F', 'G', 'F', 'A', 'C', 'G', 'G', 'D', 'G', 'F', 'E', 'A', 'D', 'G', 'E', 'G', 'A', 'F']
# Generation 17
# Best fitness in this generation: 20
# Best melody: ['E', 'F', 'F', 'G', 'F', 'A', 'C', 'G', 'G', 'D', 'G', 'F', 'E', 'A', 'D', 'G', 'E', 'G', 'A', 'F']
# Generation 18
# Best fitness in this generation: 20
# Best melody: ['E', 'F', 'F', 'G', 'F', 'A', 'C', 'G', 'G', 'D', 'G', 'F', 'E', 'A', 'D', 'G', 'E', 'G', 'A', 'F']
# Generation 19
# Best fitness in this generation: 20
# Best melody: ['E', 'F', 'F', 'G', 'F', 'A', 'C', 'G', 'G', 'D', 'G', 'F', 'E', 'A', 'D', 'G', 'E', 'G', 'A', 'F']
# Generation 20
# Best fitness in this generation: 20
# Best melody: ['E', 'F', 'F', 'G', 'F', 'A', 'C', 'G', 'G', 'D', 'G', 'F', 'E', 'A', 'D', 'G', 'E', 'G', 'A', 'F']
# Best Melody: ['E', 'F', 'F', 'G', 'F', 'A', 'C', 'G', 'G', 'D', 'G', 'F', 'E', 'A', 'D', 'G', 'E', 'G', 'A', 'F']

# %%
import mido
from mido import MidiFile, MidiTrack, Message

def melody_to_midi(melody, filename="generated_melody.mid"):
    """Convert a melody (list of note names) to a MIDI file."""
    
    # Map note names to MIDI note numbers
    note_to_midi = {
        'C': 60, 'D': 62, 'E': 64, 'F': 65, 'G': 67, 'A': 69, 'B': 71, 'Bb': 70
    }

    # Create a new MIDI file and track
    midi = MidiFile()
    track = MidiTrack()
    midi.tracks.append(track)
    
    # Add notes to the MIDI track
    for note in melody:
        midi_note = note_to_midi.get(note, 60)  # Default to C4 if note is unknown
        track.append(Message('note_on', note=midi_note, velocity=64, time=0))
        track.append(Message('note_off', note=midi_note, velocity=64, time=480))  # Duration of note

    # Save the MIDI file
    midi.save(filename)
    print(f"MIDI file saved as {filename}")

# %%
import pygame
import time

def play_midi(filename="generated_melody.mid"):
    """Play a MIDI file using pygame."""
    pygame.init()
    pygame.mixer.init()
    pygame.mixer.music.load(filename)
    pygame.mixer.music.play()

    # Wait for the music to finish playing
    while pygame.mixer.music.get_busy():
        time.sleep(0.5)

    pygame.mixer.quit()
    print("Playback finished")
# Out:
# pygame 2.6.1 (SDL 2.28.4, Python 3.9.13)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
# Assuming `best_melody` is the melody generated from the genetic algorithm
# best_melody = ['C', 'D', 'E', 'F', 'G', 'A', 'B', 'C']  # Example melody for testing

# Convert the melody to MIDI and play it
melody_to_midi(best_melody, "generated_melody.mid")
play_midi("generated_melody.mid")
# Out:
# MIDI file saved as generated_melody.mid
# Playback finished

# %% [markdown]
# # Adding time duration for notes
#
# To incorporate the duration of notes (e.g., whole notes or blancas, half notes or negras, eighth notes or corcheas), you can extend each note representation to include its duration. For example, each note could be a tuple (pitch, duration) where:
#
# pitch represents the note (e.g., 'C', 'D', etc.).
# duration represents its time value (e.g., 'whole', 'half', 'eighth').
# Here’s a brief structure:
#
# Durations (time values):
#
# Blanca (whole): Longest duration (4 beats in 4/4 time).
# Negra (half): Half the duration of a blanca (2 beats).
# Corchea (eighth): Half the duration of a negra (1 beat).

# %%
import random

# Define possible rhythmic values (duration of each note in MIDI ticks)
rhythms = ['whole', 'half', 'quarter', 'eighth', 'sixteenth']
rhythm_durations = {
    'whole': 1920,    # 4 beats
    'half': 960,      # 2 beats
    'quarter': 480,   # 1 beat
    'eighth': 240,    # 0.5 beats
    'sixteenth': 120  # 0.25 beats
}

# Define the scale (C major scale for simplicity)
scales = {
    'C_major': ['C', 'D', 'E', 'F', 'G', 'A', 'B']
}

# Melody parameters
melody_length = 100  # Length of the melody (number of notes)
population_size = 100
generations = 50
mutation_rate = 0.2  # Mutation rate for note and rhythm

def generate_melody_with_rhythm(scale):
    """Generate a random melody with notes and rhythms"""
    melody = []
    for _ in range(melody_length):
        note = random.choice(scale)  # Randomly choose a note from the scale
        rhythm = random.choice(rhythms)  # Randomly choose a rhythm
        melody.append((note, rhythm))  # Add the (note, rhythm) pair to the melody
    return melody

def fitness_with_rhythm(melody, scale):
    """Fitness function: checks if all notes are within the scale"""
    return sum([1 for note, rhythm in melody if note in scale])  # Count valid notes

def crossover_with_rhythm(parent1, parent2):
    """Single point crossover for melody with rhythms"""
    crossover_point = random.randint(1, len(parent1) - 1)  # Random crossover point
    child1 = parent1[:crossover_point] + parent2[crossover_point:]
    child2 = parent2[:crossover_point] + parent1[crossover_point:]
    return child1, child2

def mutation_with_rhythm(melody, scale):
    """Random mutation: change one note or rhythm in the melody"""
    if random.random() < mutation_rate:
        mutation_point = random.randint(0, len(melody) - 1)  # Pick a random gene to mutate
        if random.random() < 0.5:
            # Change note
            melody[mutation_point] = (random.choice(scale), melody[mutation_point][1])
        else:
            # Change rhythm
            melody[mutation_point] = (melody[mutation_point][0], random.choice(rhythms))
    return melody

def selection(population, fitness_values):
    """Select the top half of the population based on fitness"""
    selected = [melody for _, melody in sorted(zip(fitness_values, population), reverse=True)]
    return selected[:len(population) // 2]  # Select top half

def genetic_algorithm_with_rhythm(scale_name):
    scale = scales[scale_name]
    population = [generate_melody_with_rhythm(scale) for _ in range(population_size)]  # Initialize population
    
    # Main GA loop
    for generation in range(generations):
        print(f"Generation {generation + 1}")

        # Evaluate fitness of the population
        fitness_values = [fitness_with_rhythm(melody, scale) for melody in population]
        best_fitness = max(fitness_values)
        print(f"Best fitness in this generation: {best_fitness}")

        # Selection: Select top half based on fitness
        selected_population = selection(population, fitness_values)

        # Crossover: Create new population
        new_population = []
        while len(new_population) < population_size:
            parent1, parent2 = random.sample(selected_population, 2)  # Pick two parents
            child1, child2 = crossover_with_rhythm(parent1, parent2)  # Create two children
            new_population.extend([child1, child2])

        # Mutation: Apply mutation to the new population
        population = [mutation_with_rhythm(melody, scale) for melody in new_population]

        # Print the best melody from the current generation
        best_melody = population[fitness_values.index(best_fitness)]
        print(f"Best melody: {best_melody}")

    # Return the best melody from the last generation
    fitness_values = [fitness_with_rhythm(melody, scale) for melody in population]
    best_melody = population[fitness_values.index(max(fitness_values))]
    return best_melody

# Run the genetic algorithm for C Major Scale with rhythms
best_melody = genetic_algorithm_with_rhythm('C_major')
print("Best melody after evolution:", best_melody)
# Out:
# Generation 1
# Best fitness in this generation: 100
# Best melody: [('E', 'eighth'), ('A', 'eighth'), ('C', 'whole'), ('E', 'eighth'), ('D', 'sixteenth'), ('D', 'sixteenth'), ('C', 'quarter'), ('B', 'eighth'), ('E', 'whole'), ('C', 'whole'), ('G', 'half'), ('F', 'quarter'), ('B', 'sixteenth'), ('B', 'whole'), ('A', 'half'), ('B', 'sixteenth'), ('B', 'whole'), ('E', 'quarter'), ('G', 'eighth'), ('D', 'quarter'), ('C', 'half'), ('D', 'eighth'), ('F', 'half'), ('E', 'sixteenth'), ('E', 'eighth'), ('G', 'quarter'), ('C', 'whole'), ('E', 'whole'), ('B', 'sixteenth'), ('D', 'whole'), ('A', 'whole'), ('C', 'sixteenth'), ('F', 'quarter'), ('B', 'quarter'), ('A', 'half'), ('D', 'whole'), ('G', 'whole'), ('A', 'whole'), ('A', 'whole'), ('E', 'eighth'), ('E', 'quarter'), ('A', 'sixteenth'), ('G', 'whole'), ('B', 'eighth'), ('E', 'half'), ('F', 'sixteenth'), ('G', 'quarter'), ('A', 'half'), ('C', 'quarter'), ('F', 'half'), ('C', 'half'), ('D', 'half'), ('G', 'eighth'), ('D', 'sixteenth'), ('F', 'sixteenth'), ('G', 'sixteenth'), ('E', 'whole'), ('C', 'quarter'), ('A', 'sixteenth'), ('E', 'sixteenth'), ('G', 'quarter'), ('A', 'half'), ('A', 'sixteenth'), ('E', 'whole'), ('C', 'eighth'), ('B', 'sixteenth'), ('B', 'half'), ('F', 'half'), ('F', 'sixteenth'), ('C', 'quarter'), ('D', 'quarter'), ('A', 'half'), ('F', 'whole'), ('E', 'quarter'), ('C', 'whole'), ('C', 'quarter'), ('C', 'half'), ('E', 'eighth'), ('A', 'sixteenth'), ('F', 'eighth'), ('B', 'half'), ('C', 'whole'), ('F', 'quarter'), ('A', 'whole'), ('F', 'sixteenth'), ('F', 'sixteenth'), ('C', 'sixteenth'), ('G', 'half'), ('C', 'whole'), ('D', 'half'), ('G', 'sixteenth'), ('A', 'sixteenth'), ('C', 'eighth'), ('E', 'whole'), ('F', 'half'), ('G', 'sixteenth'), ('G', 'quarter'), ('E', 'sixteenth'), ('B', 'half'), ('E', 'whole')]
# Generation 2
# Best fitness in this generation: 100
# Best melody: [('G', 'quarter'), ('C', 'eighth'), ('G', 'sixteenth'), ('C', 'eighth'), ('E', 'whole'), ('G', 'sixteenth'), ('D', 'whole'), ('C', 'sixteenth'), ('B', 'half'), ('B', 'half'), ('C', 'whole'), ('B', 'whole'), ('D', 'quarter'), ('D', 'eighth'), ('C', 'whole'), ('A', 'whole'), ('G', 'quarter'), ('D', 'sixteenth'), ('E', 'sixteenth'), ('A', 'half'), ('B', 'sixteenth'), ('C', 'half'), ('F', 'sixteenth'), ('A', 'half'), ('G', 'eighth'), ('G', 'half'), ('E', 'half'), ('C', 'eighth'), ('A', 'whole'), ('D', 'quarter'), ('E', 'sixteenth'), ('G', 'quarter'), ('A', 'whole'), ('C', 'eighth'), ('C', 'whole'), ('B', 'whole'), ('E', 'whole'), ('F', 'sixteenth'), ('F', 'quarter'), ('F', 'eighth'), ('C', 'half'), ('A', 'eighth'), ('B', 'whole'), ('G', 'quarter'), ('D', 'half'), ('D', 'half'), ('B', 'whole'), ('E', 'half'), ('C', 'eighth'), ('D', 'quarter'), ('B', 'whole'), ('B', 'quarter'), ('E', 'whole'), ('A', 'whole'), ('F', 'eighth'), ('D', 'quarter'), ('G', 'quarter'), ('B', 'sixteenth'), ('B', 'eighth'), ('F', 'quarter'), ('A', 'sixteenth'), ('C', 'half'), ('C', 'quarter'), ('D', 'quarter'), ('C', 'whole'), ('E', 'whole'), ('B', 'whole'), ('G', 'quarter'), ('D', 'eighth'), ('A', 'sixteenth'), ('C', 'eighth'), ('B', 'whole'), ('C', 'quarter'), ('E', 'whole'), ('B', 'whole'), ('F', 'whole'), ('E', 'quarter'), ('F', 'whole'), ('A', 'whole'), ('A', 'whole'), ('D', 'whole'), ('E', 'sixteenth'), ('B', 'whole'), ('C', 'quarter'), ('B', 'sixteenth'), ('B', 'eighth'), ('D', 'whole'), ('A', 'whole'), ('A', 'quarter'), ('C', 'eighth'), ('F', 'whole'), ('C', 'whole'), ('G', 'half'), ('D', 'eighth'), ('G', 'whole'), ('D', 'half'), ('E', 'whole'), ('A', 'eighth'), ('F', 'whole'), ('F', 'eighth')]
# Generation 3
# Best fitness in this generation: 100
# Best melody: [('G', 'sixteenth'), ('D', 'whole'), ('A', 'half'), ('F', 'quarter'), ('B', 'quarter'), ('G', 'half'), ('A', 'whole'), ('C', 'sixteenth'), ('G', 'whole'), ('A', 'eighth'), ('E', 'sixteenth'), ('G', 'sixteenth'), ('F', 'quarter'), ('B', 'whole'), ('A', 'half'), ('E', 'half'), ('A', 'sixteenth'), ('A', 'eighth'), ('F', 'sixteenth'), ('B', 'whole'), ('E', 'sixteenth'), ('F', 'eighth'), ('C', 'whole'), ('G', 'eighth'), ('E', 'eighth'), ('B', 'sixteenth'), ('D', 'whole'), ('D', 'whole'), ('C', 'half'), ('B', 'quarter'), ('E', 'whole'), ('A', 'half'), ('A', 'half'), ('B', 'sixteenth'), ('B', 'whole'), ('A', 'quarter'), ('B', 'half'), ('E', 'whole'), ('F', 'whole'), ('C', 'whole'), ('G', 'quarter'), ('D', 'half'), ('D', 'eighth'), ('B', 'sixteenth'), ('C', 'sixteenth'), ('A', 'eighth'), ('E', 'half'), ('D', 'quarter'), ('D', 'sixteenth'), ('E', 'eighth'), ('A', 'eighth'), ('D', 'half'), ('G', 'sixteenth'), ('B', 'quarter'), ('G', 'sixteenth'), ('G', 'eighth'), ('E', 'sixteenth'), ('A', 'half'), ('E', 'whole'), ('B', 'whole'), ('B', 'half'), ('C', 'quarter'), ('A', 'whole'), ('C', 'half'), ('A', 'whole'), ('B', 'whole'), ('C', 'eighth'), ('B', 'sixteenth'), ('B', 'sixteenth'), ('B', 'eighth'), ('B', 'sixteenth'), ('G', 'whole'), ('D', 'quarter'), ('D', 'sixteenth'), ('F', 'sixteenth'), ('B', 'half'), ('C', 'sixteenth'), ('G', 'whole'), ('E', 'eighth'), ('F', 'sixteenth'), ('B', 'half'), ('G', 'whole'), ('D', 'eighth'), ('G', 'half'), ('A', 'sixteenth'), ('D', 'eighth'), ('B', 'sixteenth'), ('A', 'half'), ('G', 'eighth'), ('A', 'quarter'), ('E', 'sixteenth'), ('A', 'whole'), ('C', 'half'), ('B', 'eighth'), ('C', 'sixteenth'), ('F', 'whole'), ('B', 'half'), ('C', 'half'), ('A', 'sixteenth'), ('A', 'half')]
# Generation 4
# Best fitness in this generation: 100
# Best melody: [('G', 'quarter'), ('C', 'eighth'), ('G', 'sixteenth'), ('C', 'eighth'), ('E', 'whole'), ('G', 'sixteenth'), ('D', 'whole'), ('C', 'sixteenth'), ('B', 'half'), ('A', 'whole'), ('E', 'eighth'), ('D', 'whole'), ('A', 'quarter'), ('A', 'quarter'), ('E', 'eighth'), ('G', 'whole'), ('E', 'eighth'), ('C', 'quarter'), ('D', 'eighth'), ('B', 'half'), ('C', 'quarter'), ('G', 'half'), ('C', 'whole'), ('B', 'sixteenth'), ('G', 'half'), ('D', 'half'), ('C', 'sixteenth'), ('F', 'whole'), ('A', 'eighth'), ('D', 'quarter'), ('F', 'sixteenth'), ('E', 'sixteenth'), ('D', 'sixteenth'), ('C', 'half'), ('B', 'eighth'), ('A', 'half'), ('D', 'quarter'), ('B', 'quarter'), ('C', 'eighth'), ('A', 'half'), ('B', 'quarter'), ('E', 'whole'), ('F', 'sixteenth'), ('B', 'whole'), ('C', 'whole'), ('D', 'eighth'), ('B', 'half'), ('E', 'half'), ('B', 'half'), ('D', 'half'), ('A', 'sixteenth'), ('F', 'whole'), ('B', 'half'), ('C', 'half'), ('E', 'half'), ('C', 'whole'), ('E', 'eighth'), ('B', 'quarter'), ('E', 'half'), ('B', 'whole'), ('C', 'whole'), ('D', 'sixteenth'), ('C', 'quarter'), ('A', 'half'), ('E', 'whole'), ('D', 'whole'), ('E', 'half'), ('G', 'eighth'), ('D', 'half'), ('D', 'half'), ('F', 'whole'), ('A', 'quarter'), ('D', 'quarter'), ('D', 'eighth'), ('D', 'whole'), ('E', 'whole'), ('B', 'half'), ('B', 'quarter'), ('B', 'half'), ('D', 'sixteenth'), ('D', 'half'), ('E', 'half'), ('G', 'half'), ('D', 'eighth'), ('E', 'half'), ('G', 'half'), ('D', 'whole'), ('A', 'whole'), ('G', 'quarter'), ('C', 'eighth'), ('F', 'whole'), ('C', 'whole'), ('G', 'half'), ('D', 'eighth'), ('G', 'whole'), ('D', 'half'), ('E', 'whole'), ('G', 'whole'), ('E', 'eighth'), ('D', 'sixteenth')]
# Generation 5
# Best fitness in this generation: 100
# Best melody: [('G', 'sixteenth'), ('G', 'quarter'), ('F', 'whole'), ('C', 'quarter'), ('D', 'eighth'), ('E', 'quarter'), ('A', 'eighth'), ('F', 'sixteenth'), ('D', 'sixteenth'), ('C', 'eighth'), ('A', 'half'), ('D', 'sixteenth'), ('G', 'sixteenth'), ('E', 'eighth'), ('D', 'sixteenth'), ('C', 'quarter'), ('G', 'sixteenth'), ('F', 'half'), ('B', 'half'), ('E', 'eighth'), ('B', 'quarter'), ('F', 'sixteenth'), ('F', 'eighth'), ('A', 'half'), ('G', 'eighth'), ('G', 'half'), ('E', 'half'), ('C', 'eighth'), ('A', 'whole'), ('D', 'quarter'), ('E', 'sixteenth'), ('G', 'quarter'), ('A', 'whole'), ('C', 'eighth'), ('C', 'whole'), ('B', 'whole'), ('E', 'whole'), ('F', 'sixteenth'), ('F', 'quarter'), ('F', 'eighth'), ('C', 'half'), ('A', 'eighth'), ('B', 'whole'), ('G', 'quarter'), ('D', 'half'), ('D', 'half'), ('D', 'half'), ('D', 'eighth'), ('A', 'sixteenth'), ('G', 'quarter'), ('F', 'quarter'), ('G', 'sixteenth'), ('F', 'sixteenth'), ('E', 'sixteenth'), ('G', 'quarter'), ('B', 'quarter'), ('D', 'whole'), ('D', 'sixteenth'), ('B', 'sixteenth'), ('B', 'half'), ('B', 'eighth'), ('F', 'quarter'), ('B', 'eighth'), ('G', 'whole'), ('F', 'half'), ('A', 'quarter'), ('E', 'half'), ('E', 'quarter'), ('E', 'half'), ('D', 'quarter'), ('A', 'half'), ('E', 'sixteenth'), ('B', 'sixteenth'), ('C', 'eighth'), ('E', 'eighth'), ('E', 'eighth'), ('C', 'eighth'), ('G', 'sixteenth'), ('A', 'whole'), ('C', 'quarter'), ('C', 'eighth'), ('A', 'eighth'), ('E', 'eighth'), ('B', 'half'), ('A', 'whole'), ('C', 'whole'), ('C', 'whole'), ('C', 'sixteenth'), ('G', 'half'), ('E', 'quarter'), ('B', 'half'), ('B', 'half'), ('C', 'quarter'), ('A', 'whole'), ('C', 'eighth'), ('E', 'whole'), ('D', 'eighth'), ('C', 'whole'), ('C', 'sixteenth'), ('E', 'half')]
# Generation 6
# Best fitness in this generation: 100
# Best melody: [('G', 'whole'), ('C', 'whole'), ('C', 'quarter'), ('E', 'eighth'), ('E', 'eighth'), ('F', 'quarter'), ('G', 'eighth'), ('D', 'half'), ('E', 'quarter'), ('D', 'half'), ('D', 'whole'), ('C', 'sixteenth'), ('E', 'whole'), ('G', 'half'), ('G', 'sixteenth'), ('E', 'half'), ('G', 'whole'), ('D', 'whole'), ('D', 'eighth'), ('E', 'half'), ('A', 'quarter'), ('F', 'half'), ('F', 'sixteenth'), ('D', 'quarter'), ('G', 'eighth'), ('D', 'whole'), ('E', 'sixteenth'), ('A', 'eighth'), ('E', 'whole'), ('F', 'eighth'), ('D', 'half'), ('B', 'quarter'), ('B', 'quarter'), ('E', 'quarter'), ('A', 'half'), ('G', 'quarter'), ('D', 'quarter'), ('D', 'sixteenth'), ('G', 'quarter'), ('C', 'half'), ('E', 'whole'), ('B', 'sixteenth'), ('F', 'sixteenth'), ('D', 'quarter'), ('B', 'whole'), ('C', 'eighth'), ('F', 'whole'), ('G', 'quarter'), ('B', 'whole'), ('E', 'whole'), ('F', 'whole'), ('B', 'whole'), ('F', 'eighth'), ('A', 'half'), ('C', 'whole'), ('B', 'half'), ('G', 'eighth'), ('A', 'sixteenth'), ('B', 'whole'), ('D', 'whole'), ('F', 'eighth'), ('A', 'half'), ('D', 'whole'), ('G', 'half'), ('G', 'whole'), ('C', 'eighth'), ('B', 'half'), ('D', 'half'), ('D', 'half'), ('B', 'half'), ('D', 'half'), ('B', 'whole'), ('E', 'whole'), ('F', 'whole'), ('E', 'quarter'), ('B', 'whole'), ('G', 'eighth'), ('C', 'half'), ('F', 'eighth'), ('F', 'whole'), ('F', 'whole'), ('A', 'whole'), ('B', 'half'), ('A', 'quarter'), ('A', 'sixteenth'), ('B', 'sixteenth'), ('E', 'sixteenth'), ('B', 'whole'), ('D', 'whole'), ('G', 'sixteenth'), ('B', 'whole'), ('G', 'half'), ('D', 'half'), ('E', 'sixteenth'), ('B', 'sixteenth'), ('C', 'eighth'), ('A', 'half'), ('A', 'whole'), ('C', 'whole'), ('A', 'whole')]
# Generation 7
# Best fitness in this generation: 100
# Best melody: [('G', 'whole'), ('F', 'half'), ('F', 'sixteenth'), ('A', 'eighth'), ('D', 'half'), ('A', 'sixteenth'), ('B', 'eighth'), ('E', 'whole'), ('D', 'eighth'), ('F', 'whole'), ('A', 'eighth'), ('G', 'eighth'), ('E', 'whole'), ('A', 'half'), ('D', 'eighth'), ('F', 'eighth'), ('D', 'whole'), ('A', 'half'), ('E', 'sixteenth'), ('A', 'eighth'), ('G', 'quarter'), ('C', 'sixteenth'), ('C', 'sixteenth'), ('F', 'whole'), ('C', 'sixteenth'), ('F', 'whole'), ('E', 'half'), ('F', 'quarter'), ('A', 'whole'), ('D', 'quarter'), ('E', 'sixteenth'), ('G', 'quarter'), ('A', 'whole'), ('C', 'eighth'), ('F', 'sixteenth'), ('C', 'half'), ('B', 'sixteenth'), ('G', 'quarter'), ('C', 'quarter'), ('B', 'eighth'), ('B', 'whole'), ('G', 'sixteenth'), ('B', 'eighth'), ('C', 'eighth'), ('A', 'eighth'), ('E', 'sixteenth'), ('A', 'quarter'), ('D', 'half'), ('D', 'whole'), ('G', 'whole'), ('D', 'whole'), ('B', 'quarter'), ('E', 'whole'), ('A', 'whole'), ('F', 'eighth'), ('D', 'quarter'), ('G', 'quarter'), ('B', 'sixteenth'), ('B', 'eighth'), ('F', 'quarter'), ('A', 'sixteenth'), ('C', 'half'), ('C', 'quarter'), ('D', 'quarter'), ('C', 'whole'), ('E', 'whole'), ('B', 'whole'), ('G', 'quarter'), ('D', 'eighth'), ('A', 'sixteenth'), ('B', 'eighth'), ('B', 'whole'), ('C', 'quarter'), ('E', 'whole'), ('B', 'whole'), ('F', 'whole'), ('E', 'quarter'), ('D', 'whole'), ('B', 'whole'), ('A', 'eighth'), ('G', 'eighth'), ('C', 'sixteenth'), ('C', 'sixteenth'), ('F', 'sixteenth'), ('D', 'eighth'), ('A', 'half'), ('G', 'half'), ('E', 'whole'), ('B', 'whole'), ('D', 'whole'), ('A', 'half'), ('A', 'sixteenth'), ('G', 'whole'), ('A', 'half'), ('A', 'sixteenth'), ('C', 'quarter'), ('E', 'half'), ('G', 'sixteenth'), ('C', 'sixteenth'), ('E', 'sixteenth')]
# Generation 8
# Best fitness in this generation: 100
# Best melody: [('G', 'whole'), ('F', 'half'), ('F', 'sixteenth'), ('A', 'eighth'), ('D', 'half'), ('A', 'sixteenth'), ('B', 'eighth'), ('E', 'whole'), ('D', 'eighth'), ('F', 'whole'), ('A', 'eighth'), ('G', 'eighth'), ('E', 'whole'), ('A', 'half'), ('D', 'eighth'), ('F', 'eighth'), ('D', 'whole'), ('A', 'half'), ('E', 'sixteenth'), ('A', 'eighth'), ('G', 'quarter'), ('C', 'sixteenth'), ('E', 'eighth'), ('B', 'sixteenth'), ('G', 'half'), ('D', 'half'), ('C', 'sixteenth'), ('F', 'whole'), ('A', 'eighth'), ('D', 'quarter'), ('F', 'sixteenth'), ('E', 'sixteenth'), ('D', 'sixteenth'), ('C', 'half'), ('B', 'eighth'), ('A', 'half'), ('D', 'quarter'), ('B', 'quarter'), ('C', 'eighth'), ('A', 'half'), ('C', 'half'), ('A', 'eighth'), ('B', 'whole'), ('G', 'quarter'), ('D', 'half'), ('D', 'half'), ('B', 'whole'), ('E', 'half'), ('C', 'eighth'), ('D', 'quarter'), ('B', 'whole'), ('B', 'quarter'), ('E', 'whole'), ('A', 'whole'), ('F', 'eighth'), ('D', 'quarter'), ('G', 'quarter'), ('B', 'sixteenth'), ('B', 'eighth'), ('F', 'quarter'), ('A', 'sixteenth'), ('C', 'half'), ('C', 'quarter'), ('D', 'quarter'), ('C', 'whole'), ('E', 'whole'), ('B', 'whole'), ('G', 'quarter'), ('D', 'eighth'), ('A', 'sixteenth'), ('C', 'eighth'), ('B', 'whole'), ('C', 'quarter'), ('E', 'whole'), ('B', 'whole'), ('F', 'whole'), ('E', 'quarter'), ('F', 'whole'), ('A', 'whole'), ('A', 'whole'), ('D', 'whole'), ('E', 'sixteenth'), ('B', 'whole'), ('C', 'quarter'), ('B', 'sixteenth'), ('B', 'eighth'), ('D', 'whole'), ('A', 'whole'), ('A', 'quarter'), ('C', 'eighth'), ('F', 'whole'), ('A', 'whole'), ('C', 'sixteenth'), ('C', 'sixteenth'), ('G', 'eighth'), ('D', 'sixteenth'), ('E', 'whole'), ('F', 'half'), ('F', 'half'), ('D', 'eighth')]
# Generation 9
# Best fitness in this generation: 100
# Best melody: [('G', 'whole'), ('F', 'half'), ('F', 'sixteenth'), ('A', 'eighth'), ('D', 'half'), ('A', 'sixteenth'), ('B', 'eighth'), ('E', 'whole'), ('D', 'eighth'), ('F', 'whole'), ('A', 'eighth'), ('G', 'eighth'), ('E', 'whole'), ('A', 'half'), ('D', 'eighth'), ('F', 'eighth'), ('D', 'whole'), ('A', 'half'), ('E', 'sixteenth'), ('A', 'eighth'), ('G', 'quarter'), ('C', 'sixteenth'), ('C', 'whole'), ('B', 'sixteenth'), ('G', 'half'), ('D', 'half'), ('C', 'sixteenth'), ('F', 'whole'), ('A', 'eighth'), ('D', 'quarter'), ('F', 'sixteenth'), ('E', 'sixteenth'), ('D', 'sixteenth'), ('D', 'eighth'), ('G', 'half'), ('F', 'sixteenth'), ('D', 'quarter'), ('E', 'quarter'), ('G', 'half'), ('A', 'sixteenth'), ('C', 'quarter'), ('G', 'sixteenth'), ('D', 'eighth'), ('G', 'half'), ('A', 'eighth'), ('A', 'sixteenth'), ('C', 'half'), ('F', 'half'), ('D', 'whole'), ('D', 'quarter'), ('A', 'half'), ('B', 'half'), ('A', 'whole'), ('G', 'quarter'), ('C', 'sixteenth'), ('G', 'half'), ('E', 'whole'), ('B', 'half'), ('D', 'sixteenth'), ('E', 'eighth'), ('D', 'eighth'), ('E', 'whole'), ('C', 'half'), ('G', 'whole'), ('A', 'sixteenth'), ('G', 'sixteenth'), ('B', 'half'), ('A', 'sixteenth'), ('C', 'half'), ('D', 'whole'), ('D', 'eighth'), ('F', 'eighth'), ('C', 'sixteenth'), ('A', 'half'), ('F', 'quarter'), ('D', 'sixteenth'), ('A', 'quarter'), ('F', 'eighth'), ('G', 'sixteenth'), ('B', 'half'), ('B', 'eighth'), ('E', 'whole'), ('F', 'whole'), ('B', 'eighth'), ('A', 'eighth'), ('G', 'eighth'), ('E', 'eighth'), ('G', 'quarter'), ('G', 'whole'), ('D', 'eighth'), ('A', 'whole'), ('G', 'half'), ('B', 'quarter'), ('B', 'sixteenth'), ('D', 'eighth'), ('A', 'whole'), ('E', 'eighth'), ('E', 'sixteenth'), ('G', 'quarter'), ('A', 'whole')]
# Generation 10
# Best fitness in this generation: 100
# Best melody: [('G', 'whole'), ('F', 'half'), ('F', 'sixteenth'), ('E', 'eighth'), ('E', 'eighth'), ('F', 'quarter'), ('G', 'eighth'), ('F', 'sixteenth'), ('D', 'sixteenth'), ('C', 'eighth'), ('A', 'half'), ('D', 'sixteenth'), ('G', 'sixteenth'), ('E', 'eighth'), ('D', 'eighth'), ('F', 'eighth'), ('D', 'whole'), ('A', 'half'), ('E', 'sixteenth'), ('A', 'eighth'), ('G', 'quarter'), ('C', 'sixteenth'), ('C', 'whole'), ('B', 'sixteenth'), ('G', 'half'), ('D', 'half'), ('C', 'sixteenth'), ('F', 'whole'), ('A', 'eighth'), ('D', 'quarter'), ('F', 'sixteenth'), ('E', 'sixteenth'), ('D', 'sixteenth'), ('C', 'half'), ('B', 'eighth'), ('A', 'half'), ('D', 'quarter'), ('B', 'quarter'), ('C', 'eighth'), ('A', 'half'), ('B', 'quarter'), ('E', 'whole'), ('A', 'sixteenth'), ('B', 'whole'), ('C', 'whole'), ('D', 'eighth'), ('B', 'half'), ('D', 'half'), ('D', 'whole'), ('G', 'whole'), ('D', 'whole'), ('B', 'whole'), ('G', 'quarter'), ('E', 'sixteenth'), ('C', 'sixteenth'), ('D', 'eighth'), ('F', 'quarter'), ('C', 'sixteenth'), ('D', 'sixteenth'), ('F', 'eighth'), ('D', 'eighth'), ('C', 'whole'), ('D', 'half'), ('A', 'quarter'), ('A', 'whole'), ('E', 'sixteenth'), ('D', 'whole'), ('D', 'eighth'), ('B', 'half'), ('B', 'eighth'), ('B', 'whole'), ('F', 'quarter'), ('A', 'sixteenth'), ('C', 'half'), ('G', 'quarter'), ('C', 'whole'), ('D', 'half'), ('D', 'whole'), ('B', 'whole'), ('A', 'eighth'), ('G', 'eighth'), ('C', 'sixteenth'), ('C', 'sixteenth'), ('F', 'sixteenth'), ('D', 'eighth'), ('A', 'half'), ('G', 'half'), ('E', 'whole'), ('B', 'whole'), ('D', 'whole'), ('A', 'half'), ('A', 'sixteenth'), ('G', 'whole'), ('A', 'half'), ('A', 'sixteenth'), ('C', 'quarter'), ('E', 'half'), ('E', 'sixteenth'), ('G', 'quarter'), ('B', 'eighth')]
# Generation 11
# Best fitness in this generation: 100
# Best melody: [('G', 'whole'), ('G', 'quarter'), ('F', 'whole'), ('C', 'quarter'), ('D', 'eighth'), ('E', 'quarter'), ('A', 'half'), ('F', 'sixteenth'), ('D', 'sixteenth'), ('C', 'eighth'), ('A', 'half'), ('G', 'eighth'), ('E', 'whole'), ('A', 'half'), ('D', 'eighth'), ('F', 'eighth'), ('D', 'whole'), ('A', 'half'), ('E', 'sixteenth'), ('A', 'eighth'), ('G', 'quarter'), ('C', 'sixteenth'), ('C', 'sixteenth'), ('F', 'whole'), ('C', 'sixteenth'), ('F', 'whole'), ('E', 'half'), ('F', 'quarter'), ('A', 'whole'), ('D', 'quarter'), ('E', 'sixteenth'), ('G', 'quarter'), ('A', 'whole'), ('E', 'quarter'), ('A', 'half'), ('E', 'quarter'), ('F', 'eighth'), ('G', 'half'), ('B', 'sixteenth'), ('E', 'quarter'), ('E', 'quarter'), ('B', 'half'), ('G', 'half'), ('A', 'eighth'), ('G', 'whole'), ('E', 'whole'), ('C', 'eighth'), ('B', 'eighth'), ('E', 'quarter'), ('F', 'half'), ('C', 'half'), ('F', 'quarter'), ('F', 'quarter'), ('E', 'sixteenth'), ('C', 'whole'), ('D', 'eighth'), ('F', 'quarter'), ('C', 'sixteenth'), ('D', 'sixteenth'), ('F', 'eighth'), ('D', 'eighth'), ('C', 'whole'), ('D', 'half'), ('A', 'quarter'), ('A', 'whole'), ('E', 'sixteenth'), ('D', 'whole'), ('D', 'eighth'), ('B', 'half'), ('B', 'eighth'), ('B', 'whole'), ('F', 'quarter'), ('A', 'sixteenth'), ('C', 'half'), ('G', 'quarter'), ('C', 'whole'), ('D', 'half'), ('D', 'whole'), ('B', 'whole'), ('A', 'eighth'), ('G', 'eighth'), ('C', 'sixteenth'), ('C', 'sixteenth'), ('F', 'sixteenth'), ('D', 'eighth'), ('A', 'half'), ('G', 'half'), ('E', 'whole'), ('B', 'whole'), ('D', 'whole'), ('A', 'half'), ('A', 'sixteenth'), ('G', 'whole'), ('A', 'half'), ('A', 'sixteenth'), ('C', 'quarter'), ('E', 'half'), ('E', 'sixteenth'), ('G', 'quarter'), ('B', 'eighth')]
# Generation 12
# Best fitness in this generation: 100
# Best melody: [('G', 'whole'), ('G', 'quarter'), ('F', 'whole'), ('C', 'quarter'), ('D', 'eighth'), ('E', 'quarter'), ('B', 'eighth'), ('E', 'whole'), ('D', 'eighth'), ('F', 'whole'), ('A', 'eighth'), ('G', 'sixteenth'), ('E', 'whole'), ('A', 'half'), ('D', 'eighth'), ('F', 'eighth'), ('D', 'whole'), ('A', 'half'), ('E', 'sixteenth'), ('A', 'eighth'), ('G', 'quarter'), ('C', 'sixteenth'), ('C', 'sixteenth'), ('F', 'whole'), ('A', 'quarter'), ('D', 'quarter'), ('C', 'sixteenth'), ('F', 'whole'), ('A', 'eighth'), ('D', 'quarter'), ('F', 'sixteenth'), ('E', 'sixteenth'), ('D', 'sixteenth'), ('E', 'half'), ('B', 'eighth'), ('A', 'half'), ('D', 'quarter'), ('B', 'quarter'), ('C', 'eighth'), ('A', 'half'), ('B', 'quarter'), ('E', 'whole'), ('F', 'sixteenth'), ('B', 'whole'), ('A', 'eighth'), ('E', 'sixteenth'), ('A', 'quarter'), ('D', 'half'), ('D', 'whole'), ('G', 'whole'), ('D', 'whole'), ('B', 'quarter'), ('E', 'whole'), ('A', 'whole'), ('F', 'eighth'), ('D', 'quarter'), ('G', 'quarter'), ('B', 'sixteenth'), ('B', 'eighth'), ('F', 'quarter'), ('A', 'sixteenth'), ('C', 'half'), ('C', 'quarter'), ('D', 'quarter'), ('C', 'whole'), ('E', 'whole'), ('B', 'whole'), ('G', 'quarter'), ('D', 'eighth'), ('A', 'sixteenth'), ('B', 'quarter'), ('B', 'whole'), ('C', 'quarter'), ('E', 'whole'), ('B', 'whole'), ('F', 'whole'), ('E', 'quarter'), ('F', 'whole'), ('A', 'whole'), ('A', 'whole'), ('D', 'whole'), ('E', 'sixteenth'), ('B', 'whole'), ('C', 'quarter'), ('B', 'sixteenth'), ('B', 'eighth'), ('D', 'whole'), ('A', 'whole'), ('A', 'quarter'), ('C', 'eighth'), ('F', 'whole'), ('E', 'whole'), ('F', 'sixteenth'), ('C', 'eighth'), ('B', 'whole'), ('E', 'half'), ('G', 'eighth'), ('A', 'half'), ('F', 'half'), ('D', 'eighth')]
# Generation 13
# Best fitness in this generation: 100
# Best melody: [('G', 'whole'), ('G', 'quarter'), ('F', 'whole'), ('C', 'quarter'), ('D', 'eighth'), ('E', 'quarter'), ('B', 'eighth'), ('E', 'whole'), ('D', 'eighth'), ('F', 'whole'), ('A', 'eighth'), ('G', 'eighth'), ('E', 'whole'), ('A', 'half'), ('D', 'eighth'), ('F', 'eighth'), ('D', 'whole'), ('F', 'half'), ('D', 'eighth'), ('B', 'half'), ('C', 'quarter'), ('G', 'half'), ('C', 'whole'), ('B', 'sixteenth'), ('G', 'half'), ('D', 'half'), ('C', 'sixteenth'), ('F', 'whole'), ('A', 'eighth'), ('D', 'quarter'), ('F', 'sixteenth'), ('E', 'sixteenth'), ('D', 'sixteenth'), ('E', 'half'), ('B', 'eighth'), ('A', 'half'), ('D', 'quarter'), ('F', 'quarter'), ('C', 'eighth'), ('A', 'half'), ('B', 'quarter'), ('E', 'whole'), ('F', 'sixteenth'), ('B', 'whole'), ('C', 'whole'), ('D', 'eighth'), ('B', 'half'), ('E', 'half'), ('B', 'half'), ('A', 'eighth'), ('F', 'sixteenth'), ('D', 'whole'), ('D', 'half'), ('C', 'eighth'), ('C', 'whole'), ('A', 'half'), ('G', 'quarter'), ('B', 'sixteenth'), ('B', 'eighth'), ('F', 'quarter'), ('A', 'sixteenth'), ('C', 'half'), ('C', 'quarter'), ('D', 'quarter'), ('C', 'whole'), ('E', 'whole'), ('B', 'whole'), ('G', 'quarter'), ('D', 'eighth'), ('A', 'sixteenth'), ('B', 'eighth'), ('B', 'whole'), ('C', 'quarter'), ('E', 'whole'), ('B', 'whole'), ('F', 'whole'), ('E', 'quarter'), ('F', 'whole'), ('A', 'whole'), ('A', 'whole'), ('D', 'whole'), ('E', 'eighth'), ('B', 'whole'), ('C', 'quarter'), ('B', 'sixteenth'), ('B', 'eighth'), ('D', 'whole'), ('A', 'whole'), ('A', 'quarter'), ('C', 'eighth'), ('F', 'whole'), ('C', 'whole'), ('G', 'half'), ('D', 'eighth'), ('G', 'whole'), ('D', 'half'), ('E', 'half'), ('G', 'sixteenth'), ('C', 'sixteenth'), ('E', 'sixteenth')]
# Generation 14
# Best fitness in this generation: 100
# Best melody: [('G', 'whole'), ('G', 'quarter'), ('F', 'whole'), ('C', 'quarter'), ('D', 'half'), ('A', 'sixteenth'), ('B', 'eighth'), ('E', 'whole'), ('D', 'eighth'), ('F', 'whole'), ('A', 'eighth'), ('G', 'sixteenth'), ('E', 'whole'), ('A', 'half'), ('D', 'eighth'), ('F', 'eighth'), ('D', 'whole'), ('A', 'half'), ('E', 'sixteenth'), ('A', 'eighth'), ('A', 'quarter'), ('F', 'half'), ('E', 'eighth'), ('B', 'sixteenth'), ('A', 'quarter'), ('D', 'quarter'), ('E', 'whole'), ('F', 'half'), ('D', 'sixteenth'), ('E', 'half'), ('B', 'eighth'), ('E', 'eighth'), ('D', 'sixteenth'), ('D', 'quarter'), ('F', 'sixteenth'), ('C', 'half'), ('B', 'sixteenth'), ('G', 'quarter'), ('C', 'eighth'), ('A', 'half'), ('C', 'half'), ('A', 'eighth'), ('F', 'sixteenth'), ('E', 'whole'), ('C', 'whole'), ('D', 'eighth'), ('B', 'half'), ('E', 'half'), ('B', 'half'), ('A', 'eighth'), ('F', 'sixteenth'), ('C', 'quarter'), ('B', 'half'), ('C', 'half'), ('E', 'half'), ('C', 'whole'), ('E', 'eighth'), ('B', 'quarter'), ('E', 'half'), ('B', 'whole'), ('C', 'whole'), ('D', 'sixteenth'), ('F', 'half'), ('E', 'sixteenth'), ('C', 'sixteenth'), ('D', 'half'), ('C', 'sixteenth'), ('A', 'sixteenth'), ('A', 'half'), ('E', 'quarter'), ('F', 'whole'), ('G', 'eighth'), ('F', 'half'), ('A', 'half'), ('D', 'half'), ('G', 'half'), ('G', 'sixteenth'), ('A', 'whole'), ('A', 'half'), ('F', 'whole'), ('B', 'whole'), ('F', 'sixteenth'), ('D', 'eighth'), ('F', 'quarter'), ('A', 'eighth'), ('G', 'eighth'), ('E', 'eighth'), ('G', 'quarter'), ('G', 'whole'), ('D', 'eighth'), ('C', 'eighth'), ('E', 'whole'), ('F', 'sixteenth'), ('C', 'eighth'), ('B', 'whole'), ('E', 'half'), ('G', 'eighth'), ('A', 'half'), ('F', 'half'), ('D', 'eighth')]
# Generation 15
# Best fitness in this generation: 100
# Best melody: [('G', 'whole'), ('G', 'quarter'), ('F', 'whole'), ('C', 'quarter'), ('D', 'eighth'), ('E', 'quarter'), ('B', 'eighth'), ('E', 'whole'), ('D', 'eighth'), ('F', 'whole'), ('A', 'eighth'), ('G', 'sixteenth'), ('E', 'whole'), ('A', 'half'), ('D', 'eighth'), ('F', 'eighth'), ('D', 'whole'), ('A', 'half'), ('E', 'sixteenth'), ('A', 'eighth'), ('G', 'quarter'), ('C', 'sixteenth'), ('C', 'sixteenth'), ('F', 'whole'), ('A', 'quarter'), ('D', 'quarter'), ('C', 'sixteenth'), ('F', 'whole'), ('A', 'eighth'), ('D', 'quarter'), ('F', 'sixteenth'), ('E', 'sixteenth'), ('D', 'sixteenth'), ('E', 'half'), ('B', 'eighth'), ('A', 'half'), ('D', 'quarter'), ('B', 'quarter'), ('C', 'eighth'), ('A', 'half'), ('B', 'quarter'), ('E', 'whole'), ('F', 'sixteenth'), ('B', 'whole'), ('G', 'whole'), ('E', 'whole'), ('C', 'eighth'), ('B', 'eighth'), ('E', 'quarter'), ('F', 'half'), ('C', 'half'), ('C', 'quarter'), ('B', 'half'), ('B', 'sixteenth'), ('G', 'sixteenth'), ('A', 'half'), ('E', 'half'), ('D', 'quarter'), ('E', 'eighth'), ('C', 'half'), ('E', 'whole'), ('E', 'eighth'), ('B', 'eighth'), ('B', 'eighth'), ('E', 'half'), ('A', 'half'), ('D', 'eighth'), ('G', 'sixteenth'), ('C', 'half'), ('G', 'eighth'), ('F', 'quarter'), ('E', 'sixteenth'), ('F', 'whole'), ('B', 'half'), ('B', 'quarter'), ('C', 'half'), ('C', 'sixteenth'), ('G', 'quarter'), ('G', 'eighth'), ('D', 'half'), ('C', 'sixteenth'), ('E', 'sixteenth'), ('G', 'eighth'), ('F', 'eighth'), ('E', 'half'), ('C', 'eighth'), ('B', 'whole'), ('G', 'quarter'), ('G', 'whole'), ('D', 'eighth'), ('C', 'eighth'), ('E', 'whole'), ('F', 'sixteenth'), ('C', 'eighth'), ('B', 'whole'), ('E', 'half'), ('G', 'eighth'), ('A', 'eighth'), ('B', 'whole'), ('F', 'eighth')]
# Generation 16
# Best fitness in this generation: 100
# Best melody: [('G', 'whole'), ('G', 'quarter'), ('F', 'whole'), ('C', 'quarter'), ('D', 'half'), ('A', 'sixteenth'), ('B', 'eighth'), ('E', 'whole'), ('D', 'eighth'), ('F', 'whole'), ('A', 'eighth'), ('G', 'sixteenth'), ('E', 'whole'), ('A', 'half'), ('D', 'eighth'), ('F', 'eighth'), ('D', 'whole'), ('A', 'half'), ('E', 'sixteenth'), ('A', 'eighth'), ('G', 'quarter'), ('C', 'sixteenth'), ('C', 'sixteenth'), ('F', 'whole'), ('A', 'quarter'), ('D', 'quarter'), ('C', 'sixteenth'), ('F', 'whole'), ('A', 'eighth'), ('D', 'quarter'), ('F', 'sixteenth'), ('E', 'sixteenth'), ('D', 'sixteenth'), ('E', 'half'), ('B', 'eighth'), ('A', 'half'), ('D', 'quarter'), ('B', 'quarter'), ('C', 'eighth'), ('A', 'half'), ('B', 'quarter'), ('E', 'whole'), ('F', 'sixteenth'), ('B', 'whole'), ('A', 'eighth'), ('E', 'sixteenth'), ('A', 'quarter'), ('D', 'half'), ('D', 'whole'), ('G', 'whole'), ('D', 'whole'), ('B', 'quarter'), ('E', 'whole'), ('A', 'whole'), ('F', 'eighth'), ('D', 'quarter'), ('G', 'quarter'), ('B', 'sixteenth'), ('G', 'sixteenth'), ('B', 'half'), ('F', 'whole'), ('B', 'sixteenth'), ('A', 'half'), ('B', 'half'), ('B', 'sixteenth'), ('C', 'whole'), ('B', 'whole'), ('G', 'quarter'), ('D', 'eighth'), ('A', 'sixteenth'), ('B', 'whole'), ('B', 'whole'), ('C', 'quarter'), ('E', 'whole'), ('B', 'whole'), ('C', 'whole'), ('D', 'half'), ('D', 'whole'), ('B', 'whole'), ('A', 'whole'), ('D', 'whole'), ('E', 'eighth'), ('B', 'whole'), ('F', 'quarter'), ('A', 'eighth'), ('G', 'eighth'), ('E', 'eighth'), ('G', 'quarter'), ('G', 'whole'), ('B', 'eighth'), ('C', 'eighth'), ('E', 'whole'), ('F', 'sixteenth'), ('C', 'eighth'), ('B', 'whole'), ('E', 'half'), ('G', 'eighth'), ('A', 'half'), ('F', 'half'), ('D', 'eighth')]
# Generation 17
# Best fitness in this generation: 100
# Best melody: [('G', 'whole'), ('G', 'quarter'), ('F', 'whole'), ('C', 'quarter'), ('D', 'half'), ('A', 'sixteenth'), ('B', 'eighth'), ('E', 'whole'), ('D', 'eighth'), ('F', 'whole'), ('A', 'eighth'), ('G', 'sixteenth'), ('E', 'whole'), ('A', 'half'), ('D', 'eighth'), ('F', 'eighth'), ('D', 'whole'), ('A', 'half'), ('E', 'sixteenth'), ('A', 'eighth'), ('A', 'quarter'), ('F', 'half'), ('E', 'whole'), ('D', 'sixteenth'), ('B', 'half'), ('F', 'sixteenth'), ('F', 'eighth'), ('G', 'sixteenth'), ('E', 'sixteenth'), ('E', 'quarter'), ('E', 'half'), ('E', 'sixteenth'), ('E', 'quarter'), ('E', 'whole'), ('A', 'half'), ('E', 'quarter'), ('F', 'eighth'), ('G', 'half'), ('B', 'sixteenth'), ('E', 'quarter'), ('E', 'quarter'), ('B', 'half'), ('G', 'half'), ('A', 'eighth'), ('G', 'whole'), ('C', 'eighth'), ('D', 'whole'), ('F', 'half'), ('F', 'eighth'), ('F', 'whole'), ('C', 'sixteenth'), ('C', 'quarter'), ('B', 'half'), ('B', 'sixteenth'), ('G', 'sixteenth'), ('A', 'half'), ('E', 'half'), ('D', 'quarter'), ('E', 'eighth'), ('C', 'half'), ('E', 'whole'), ('E', 'eighth'), ('B', 'eighth'), ('B', 'eighth'), ('E', 'half'), ('A', 'half'), ('D', 'eighth'), ('G', 'sixteenth'), ('C', 'half'), ('G', 'eighth'), ('F', 'quarter'), ('E', 'sixteenth'), ('F', 'whole'), ('D', 'half'), ('B', 'quarter'), ('C', 'half'), ('C', 'sixteenth'), ('G', 'quarter'), ('G', 'eighth'), ('D', 'half'), ('C', 'sixteenth'), ('E', 'sixteenth'), ('G', 'eighth'), ('F', 'eighth'), ('E', 'half'), ('C', 'eighth'), ('E', 'eighth'), ('G', 'quarter'), ('G', 'whole'), ('D', 'eighth'), ('C', 'eighth'), ('E', 'whole'), ('F', 'sixteenth'), ('C', 'eighth'), ('B', 'whole'), ('D', 'sixteenth'), ('E', 'whole'), ('F', 'half'), ('F', 'half'), ('A', 'whole')]
# Generation 18
# Best fitness in this generation: 100
# Best melody: [('G', 'whole'), ('G', 'quarter'), ('F', 'whole'), ('C', 'quarter'), ('D', 'whole'), ('E', 'quarter'), ('B', 'eighth'), ('E', 'whole'), ('D', 'eighth'), ('F', 'whole'), ('A', 'eighth'), ('G', 'eighth'), ('E', 'whole'), ('A', 'half'), ('D', 'eighth'), ('F', 'eighth'), ('D', 'whole'), ('A', 'half'), ('E', 'sixteenth'), ('E', 'half'), ('A', 'quarter'), ('G', 'half'), ('C', 'whole'), ('B', 'sixteenth'), ('G', 'half'), ('D', 'half'), ('C', 'sixteenth'), ('F', 'whole'), ('A', 'eighth'), ('D', 'quarter'), ('F', 'sixteenth'), ('E', 'sixteenth'), ('F', 'sixteenth'), ('E', 'half'), ('B', 'eighth'), ('A', 'half'), ('D', 'quarter'), ('B', 'quarter'), ('C', 'eighth'), ('A', 'half'), ('B', 'quarter'), ('E', 'whole'), ('F', 'sixteenth'), ('B', 'whole'), ('A', 'eighth'), ('E', 'sixteenth'), ('A', 'quarter'), ('D', 'half'), ('D', 'whole'), ('G', 'whole'), ('D', 'whole'), ('B', 'quarter'), ('E', 'whole'), ('A', 'whole'), ('F', 'eighth'), ('D', 'quarter'), ('G', 'quarter'), ('B', 'sixteenth'), ('B', 'eighth'), ('F', 'quarter'), ('B', 'half'), ('B', 'sixteenth'), ('A', 'half'), ('G', 'whole'), ('A', 'sixteenth'), ('G', 'sixteenth'), ('B', 'half'), ('A', 'sixteenth'), ('C', 'half'), ('D', 'whole'), ('D', 'eighth'), ('F', 'eighth'), ('C', 'sixteenth'), ('A', 'half'), ('D', 'half'), ('G', 'half'), ('G', 'sixteenth'), ('G', 'whole'), ('A', 'whole'), ('A', 'whole'), ('D', 'whole'), ('E', 'eighth'), ('B', 'whole'), ('F', 'sixteenth'), ('D', 'eighth'), ('A', 'half'), ('G', 'half'), ('E', 'whole'), ('B', 'whole'), ('D', 'whole'), ('A', 'half'), ('A', 'sixteenth'), ('G', 'whole'), ('A', 'half'), ('A', 'sixteenth'), ('C', 'quarter'), ('E', 'half'), ('E', 'sixteenth'), ('G', 'quarter'), ('B', 'eighth')]
# Generation 19
# Best fitness in this generation: 100
# Best melody: [('G', 'whole'), ('G', 'quarter'), ('F', 'whole'), ('C', 'quarter'), ('D', 'half'), ('A', 'sixteenth'), ('B', 'eighth'), ('E', 'whole'), ('D', 'eighth'), ('F', 'whole'), ('A', 'eighth'), ('G', 'sixteenth'), ('E', 'whole'), ('A', 'half'), ('D', 'eighth'), ('F', 'eighth'), ('D', 'whole'), ('F', 'half'), ('D', 'eighth'), ('B', 'half'), ('C', 'quarter'), ('G', 'half'), ('C', 'whole'), ('B', 'sixteenth'), ('G', 'half'), ('D', 'half'), ('C', 'sixteenth'), ('F', 'whole'), ('A', 'eighth'), ('D', 'quarter'), ('F', 'sixteenth'), ('E', 'sixteenth'), ('D', 'sixteenth'), ('E', 'half'), ('B', 'eighth'), ('A', 'half'), ('D', 'quarter'), ('F', 'quarter'), ('C', 'eighth'), ('A', 'half'), ('B', 'quarter'), ('E', 'whole'), ('F', 'sixteenth'), ('B', 'whole'), ('A', 'eighth'), ('E', 'sixteenth'), ('A', 'quarter'), ('D', 'half'), ('D', 'whole'), ('G', 'whole'), ('D', 'whole'), ('B', 'quarter'), ('E', 'whole'), ('A', 'whole'), ('F', 'eighth'), ('D', 'quarter'), ('G', 'quarter'), ('B', 'sixteenth'), ('G', 'sixteenth'), ('B', 'half'), ('F', 'whole'), ('B', 'sixteenth'), ('A', 'half'), ('B', 'half'), ('B', 'sixteenth'), ('C', 'whole'), ('B', 'whole'), ('G', 'quarter'), ('D', 'eighth'), ('A', 'sixteenth'), ('B', 'eighth'), ('B', 'whole'), ('C', 'quarter'), ('E', 'whole'), ('B', 'whole'), ('C', 'whole'), ('D', 'half'), ('D', 'eighth'), ('B', 'whole'), ('A', 'eighth'), ('G', 'eighth'), ('C', 'sixteenth'), ('C', 'sixteenth'), ('F', 'sixteenth'), ('D', 'eighth'), ('A', 'half'), ('G', 'half'), ('A', 'whole'), ('A', 'quarter'), ('C', 'eighth'), ('F', 'whole'), ('A', 'sixteenth'), ('C', 'sixteenth'), ('C', 'sixteenth'), ('G', 'eighth'), ('D', 'sixteenth'), ('E', 'whole'), ('F', 'half'), ('F', 'half'), ('D', 'eighth')]
# Generation 20
# Best fitness in this generation: 100
# Best melody: [('G', 'whole'), ('G', 'quarter'), ('F', 'whole'), ('C', 'quarter'), ('D', 'whole'), ('E', 'quarter'), ('B', 'eighth'), ('E', 'whole'), ('D', 'eighth'), ('F', 'whole'), ('A', 'eighth'), ('G', 'eighth'), ('E', 'whole'), ('A', 'half'), ('D', 'eighth'), ('F', 'eighth'), ('D', 'whole'), ('A', 'half'), ('E', 'sixteenth'), ('E', 'half'), ('A', 'quarter'), ('G', 'half'), ('C', 'whole'), ('B', 'sixteenth'), ('G', 'half'), ('D', 'half'), ('C', 'sixteenth'), ('F', 'whole'), ('A', 'eighth'), ('D', 'quarter'), ('F', 'sixteenth'), ('E', 'sixteenth'), ('F', 'sixteenth'), ('E', 'half'), ('B', 'eighth'), ('A', 'half'), ('D', 'quarter'), ('B', 'quarter'), ('C', 'eighth'), ('A', 'half'), ('B', 'quarter'), ('E', 'whole'), ('F', 'sixteenth'), ('B', 'whole'), ('A', 'eighth'), ('F', 'sixteenth'), ('A', 'quarter'), ('D', 'half'), ('D', 'whole'), ('G', 'whole'), ('D', 'whole'), ('B', 'quarter'), ('E', 'whole'), ('A', 'whole'), ('F', 'eighth'), ('D', 'quarter'), ('G', 'quarter'), ('B', 'sixteenth'), ('D', 'sixteenth'), ('F', 'quarter'), ('A', 'sixteenth'), ('C', 'half'), ('C', 'quarter'), ('D', 'quarter'), ('C', 'whole'), ('E', 'whole'), ('B', 'whole'), ('G', 'quarter'), ('D', 'eighth'), ('A', 'sixteenth'), ('B', 'eighth'), ('B', 'whole'), ('C', 'quarter'), ('E', 'whole'), ('B', 'whole'), ('F', 'whole'), ('E', 'quarter'), ('F', 'whole'), ('A', 'whole'), ('A', 'whole'), ('D', 'whole'), ('E', 'eighth'), ('B', 'half'), ('C', 'sixteenth'), ('F', 'whole'), ('B', 'eighth'), ('A', 'sixteenth'), ('C', 'whole'), ('G', 'whole'), ('A', 'quarter'), ('E', 'quarter'), ('A', 'whole'), ('C', 'sixteenth'), ('C', 'whole'), ('G', 'half'), ('D', 'sixteenth'), ('E', 'whole'), ('F', 'half'), ('E', 'whole'), ('C', 'whole')]
# Generation 21
# Best fitness in this generation: 100
# Best melody: [('G', 'whole'), ('G', 'quarter'), ('F', 'whole'), ('C', 'quarter'), ('D', 'whole'), ('E', 'quarter'), ('B', 'eighth'), ('E', 'whole'), ('D', 'eighth'), ('F', 'whole'), ('A', 'eighth'), ('G', 'sixteenth'), ('E', 'whole'), ('A', 'half'), ('D', 'eighth'), ('F', 'eighth'), ('D', 'whole'), ('F', 'half'), ('D', 'eighth'), ('B', 'half'), ('C', 'quarter'), ('G', 'half'), ('C', 'whole'), ('B', 'sixteenth'), ('G', 'half'), ('D', 'half'), ('C', 'sixteenth'), ('F', 'whole'), ('A', 'eighth'), ('D', 'quarter'), ('F', 'sixteenth'), ('E', 'sixteenth'), ('D', 'sixteenth'), ('E', 'half'), ('B', 'eighth'), ('A', 'half'), ('D', 'quarter'), ('F', 'quarter'), ('C', 'eighth'), ('A', 'half'), ('B', 'quarter'), ('E', 'whole'), ('F', 'sixteenth'), ('B', 'whole'), ('C', 'whole'), ('D', 'eighth'), ('B', 'half'), ('E', 'half'), ('B', 'half'), ('A', 'eighth'), ('F', 'sixteenth'), ('D', 'whole'), ('B', 'half'), ('B', 'sixteenth'), ('G', 'sixteenth'), ('A', 'half'), ('G', 'quarter'), ('B', 'sixteenth'), ('D', 'sixteenth'), ('F', 'quarter'), ('A', 'sixteenth'), ('C', 'half'), ('C', 'quarter'), ('D', 'quarter'), ('C', 'whole'), ('E', 'whole'), ('B', 'whole'), ('G', 'quarter'), ('D', 'eighth'), ('A', 'sixteenth'), ('B', 'eighth'), ('B', 'whole'), ('C', 'quarter'), ('E', 'whole'), ('B', 'whole'), ('F', 'whole'), ('E', 'quarter'), ('F', 'whole'), ('A', 'whole'), ('A', 'whole'), ('D', 'whole'), ('E', 'sixteenth'), ('B', 'whole'), ('C', 'quarter'), ('B', 'sixteenth'), ('B', 'eighth'), ('D', 'whole'), ('A', 'whole'), ('A', 'quarter'), ('C', 'eighth'), ('F', 'whole'), ('A', 'whole'), ('C', 'sixteenth'), ('C', 'sixteenth'), ('G', 'eighth'), ('D', 'sixteenth'), ('E', 'whole'), ('F', 'half'), ('F', 'half'), ('D', 'eighth')]
# Generation 22
# Best fitness in this generation: 100
# Best melody: [('G', 'whole'), ('G', 'quarter'), ('F', 'whole'), ('C', 'quarter'), ('D', 'whole'), ('E', 'quarter'), ('B', 'eighth'), ('E', 'whole'), ('D', 'eighth'), ('F', 'whole'), ('A', 'eighth'), ('G', 'sixteenth'), ('A', 'whole'), ('A', 'half'), ('D', 'eighth'), ('F', 'eighth'), ('D', 'whole'), ('A', 'half'), ('D', 'eighth'), ('B', 'half'), ('C', 'quarter'), ('G', 'half'), ('C', 'whole'), ('B', 'sixteenth'), ('G', 'half'), ('D', 'half'), ('C', 'sixteenth'), ('F', 'whole'), ('A', 'eighth'), ('D', 'quarter'), ('F', 'sixteenth'), ('E', 'sixteenth'), ('D', 'sixteenth'), ('E', 'half'), ('B', 'eighth'), ('A', 'half'), ('D', 'quarter'), ('B', 'quarter'), ('C', 'eighth'), ('A', 'half'), ('B', 'quarter'), ('E', 'whole'), ('F', 'sixteenth'), ('B', 'whole'), ('A', 'eighth'), ('E', 'sixteenth'), ('A', 'quarter'), ('D', 'half'), ('D', 'whole'), ('G', 'whole'), ('D', 'whole'), ('B', 'quarter'), ('E', 'whole'), ('A', 'whole'), ('F', 'eighth'), ('D', 'quarter'), ('G', 'quarter'), ('B', 'sixteenth'), ('G', 'sixteenth'), ('B', 'half'), ('F', 'whole'), ('B', 'sixteenth'), ('A', 'half'), ('B', 'half'), ('B', 'sixteenth'), ('C', 'whole'), ('B', 'whole'), ('G', 'quarter'), ('D', 'eighth'), ('A', 'sixteenth'), ('B', 'whole'), ('B', 'whole'), ('C', 'quarter'), ('E', 'whole'), ('B', 'whole'), ('F', 'whole'), ('E', 'quarter'), ('G', 'whole'), ('G', 'half'), ('C', 'quarter'), ('E', 'eighth'), ('A', 'quarter'), ('B', 'half'), ('C', 'sixteenth'), ('F', 'whole'), ('B', 'eighth'), ('A', 'sixteenth'), ('C', 'whole'), ('G', 'whole'), ('A', 'quarter'), ('E', 'quarter'), ('A', 'whole'), ('C', 'sixteenth'), ('C', 'whole'), ('G', 'eighth'), ('D', 'sixteenth'), ('E', 'whole'), ('F', 'half'), ('F', 'half'), ('A', 'whole')]
# Generation 23
# Best fitness in this generation: 100
# Best melody: [('G', 'whole'), ('G', 'quarter'), ('F', 'whole'), ('F', 'quarter'), ('D', 'half'), ('A', 'sixteenth'), ('B', 'eighth'), ('E', 'whole'), ('D', 'eighth'), ('F', 'whole'), ('A', 'eighth'), ('G', 'sixteenth'), ('E', 'whole'), ('A', 'half'), ('D', 'eighth'), ('F', 'eighth'), ('D', 'whole'), ('A', 'half'), ('E', 'sixteenth'), ('E', 'half'), ('A', 'quarter'), ('G', 'quarter'), ('C', 'whole'), ('B', 'sixteenth'), ('G', 'half'), ('D', 'half'), ('C', 'sixteenth'), ('F', 'whole'), ('A', 'eighth'), ('D', 'quarter'), ('F', 'sixteenth'), ('E', 'sixteenth'), ('F', 'sixteenth'), ('E', 'half'), ('B', 'eighth'), ('A', 'half'), ('D', 'quarter'), ('B', 'quarter'), ('C', 'eighth'), ('A', 'half'), ('B', 'quarter'), ('E', 'whole'), ('F', 'sixteenth'), ('B', 'whole'), ('A', 'eighth'), ('E', 'sixteenth'), ('A', 'quarter'), ('D', 'half'), ('D', 'whole'), ('G', 'whole'), ('D', 'whole'), ('B', 'quarter'), ('E', 'whole'), ('A', 'whole'), ('F', 'eighth'), ('D', 'quarter'), ('G', 'quarter'), ('B', 'sixteenth'), ('B', 'eighth'), ('F', 'quarter'), ('B', 'half'), ('B', 'sixteenth'), ('A', 'half'), ('G', 'whole'), ('A', 'sixteenth'), ('G', 'sixteenth'), ('B', 'half'), ('A', 'sixteenth'), ('C', 'half'), ('D', 'whole'), ('D', 'eighth'), ('F', 'eighth'), ('C', 'sixteenth'), ('A', 'half'), ('D', 'half'), ('G', 'half'), ('G', 'sixteenth'), ('G', 'whole'), ('G', 'half'), ('A', 'eighth'), ('G', 'eighth'), ('C', 'sixteenth'), ('C', 'sixteenth'), ('F', 'sixteenth'), ('D', 'eighth'), ('G', 'eighth'), ('E', 'eighth'), ('G', 'quarter'), ('G', 'whole'), ('D', 'eighth'), ('C', 'eighth'), ('E', 'whole'), ('F', 'sixteenth'), ('C', 'eighth'), ('B', 'whole'), ('E', 'half'), ('G', 'eighth'), ('A', 'half'), ('F', 'half'), ('D', 'eighth')]
# Generation 24
# Best fitness in this generation: 100
# Best melody: [('G', 'whole'), ('G', 'quarter'), ('F', 'whole'), ('F', 'quarter'), ('D', 'half'), ('A', 'sixteenth'), ('B', 'eighth'), ('E', 'whole'), ('D', 'eighth'), ('F', 'whole'), ('A', 'eighth'), ('G', 'sixteenth'), ('E', 'whole'), ('A', 'half'), ('D', 'eighth'), ('F', 'eighth'), ('D', 'whole'), ('A', 'half'), ('E', 'sixteenth'), ('A', 'eighth'), ('A', 'quarter'), ('F', 'half'), ('E', 'eighth'), ('B', 'sixteenth'), ('A', 'quarter'), ('D', 'quarter'), ('E', 'whole'), ('F', 'half'), ('D', 'sixteenth'), ('E', 'half'), ('B', 'eighth'), ('E', 'eighth'), ('D', 'sixteenth'), ('D', 'quarter'), ('F', 'sixteenth'), ('C', 'half'), ('B', 'sixteenth'), ('G', 'quarter'), ('C', 'eighth'), ('A', 'half'), ('C', 'half'), ('A', 'eighth'), ('F', 'sixteenth'), ('E', 'whole'), ('C', 'whole'), ('F', 'sixteenth'), ('A', 'quarter'), ('D', 'half'), ('D', 'whole'), ('G', 'whole'), ('D', 'whole'), ('B', 'quarter'), ('E', 'whole'), ('A', 'whole'), ('F', 'eighth'), ('D', 'quarter'), ('E', 'half'), ('D', 'quarter'), ('E', 'eighth'), ('C', 'half'), ('E', 'whole'), ('E', 'eighth'), ('B', 'eighth'), ('B', 'eighth'), ('E', 'half'), ('A', 'half'), ('D', 'eighth'), ('G', 'sixteenth'), ('D', 'eighth'), ('A', 'sixteenth'), ('B', 'eighth'), ('B', 'whole'), ('C', 'quarter'), ('E', 'whole'), ('B', 'whole'), ('F', 'whole'), ('E', 'quarter'), ('F', 'whole'), ('A', 'whole'), ('A', 'whole'), ('D', 'whole'), ('E', 'sixteenth'), ('F', 'whole'), ('C', 'quarter'), ('B', 'sixteenth'), ('B', 'eighth'), ('D', 'whole'), ('E', 'whole'), ('B', 'whole'), ('D', 'whole'), ('E', 'quarter'), ('A', 'whole'), ('C', 'sixteenth'), ('C', 'whole'), ('G', 'half'), ('D', 'sixteenth'), ('E', 'whole'), ('F', 'half'), ('E', 'whole'), ('B', 'eighth')]
# Generation 25
# Best fitness in this generation: 100
# Best melody: [('G', 'whole'), ('G', 'quarter'), ('F', 'whole'), ('F', 'quarter'), ('D', 'half'), ('A', 'sixteenth'), ('B', 'eighth'), ('E', 'whole'), ('D', 'eighth'), ('F', 'whole'), ('A', 'eighth'), ('G', 'sixteenth'), ('E', 'whole'), ('A', 'half'), ('D', 'eighth'), ('F', 'eighth'), ('D', 'whole'), ('A', 'half'), ('E', 'sixteenth'), ('E', 'half'), ('A', 'quarter'), ('G', 'half'), ('C', 'whole'), ('B', 'sixteenth'), ('G', 'half'), ('D', 'half'), ('C', 'sixteenth'), ('F', 'whole'), ('A', 'eighth'), ('D', 'quarter'), ('F', 'sixteenth'), ('E', 'sixteenth'), ('F', 'sixteenth'), ('E', 'half'), ('B', 'eighth'), ('A', 'half'), ('D', 'quarter'), ('B', 'quarter'), ('C', 'eighth'), ('A', 'half'), ('B', 'quarter'), ('E', 'whole'), ('F', 'sixteenth'), ('E', 'whole'), ('C', 'whole'), ('D', 'eighth'), ('B', 'half'), ('E', 'half'), ('B', 'half'), ('A', 'eighth'), ('F', 'sixteenth'), ('C', 'quarter'), ('F', 'quarter'), ('E', 'sixteenth'), ('C', 'whole'), ('D', 'eighth'), ('F', 'quarter'), ('C', 'sixteenth'), ('D', 'sixteenth'), ('F', 'eighth'), ('D', 'eighth'), ('C', 'whole'), ('B', 'eighth'), ('B', 'eighth'), ('E', 'half'), ('A', 'half'), ('D', 'eighth'), ('G', 'sixteenth'), ('C', 'whole'), ('G', 'eighth'), ('F', 'quarter'), ('E', 'sixteenth'), ('F', 'whole'), ('E', 'whole'), ('B', 'whole'), ('F', 'whole'), ('E', 'quarter'), ('F', 'whole'), ('A', 'whole'), ('A', 'whole'), ('D', 'whole'), ('E', 'eighth'), ('B', 'half'), ('C', 'sixteenth'), ('F', 'whole'), ('B', 'eighth'), ('D', 'whole'), ('A', 'whole'), ('A', 'quarter'), ('C', 'eighth'), ('F', 'whole'), ('C', 'whole'), ('G', 'half'), ('G', 'eighth'), ('G', 'whole'), ('C', 'half'), ('E', 'whole'), ('A', 'eighth'), ('F', 'whole'), ('F', 'eighth')]
# Generation 26
# Best fitness in this generation: 100
# Best melody: [('G', 'whole'), ('G', 'quarter'), ('F', 'whole'), ('F', 'quarter'), ('D', 'whole'), ('E', 'quarter'), ('B', 'eighth'), ('E', 'whole'), ('D', 'eighth'), ('F', 'whole'), ('A', 'eighth'), ('G', 'sixteenth'), ('E', 'whole'), ('A', 'half'), ('D', 'eighth'), ('F', 'eighth'), ('D', 'whole'), ('A', 'half'), ('E', 'sixteenth'), ('E', 'half'), ('C', 'quarter'), ('G', 'half'), ('C', 'whole'), ('B', 'sixteenth'), ('B', 'half'), ('D', 'half'), ('C', 'sixteenth'), ('F', 'whole'), ('A', 'eighth'), ('D', 'quarter'), ('F', 'sixteenth'), ('E', 'sixteenth'), ('D', 'sixteenth'), ('E', 'half'), ('B', 'eighth'), ('A', 'half'), ('D', 'quarter'), ('B', 'quarter'), ('C', 'eighth'), ('A', 'half'), ('B', 'quarter'), ('E', 'whole'), ('F', 'sixteenth'), ('B', 'whole'), ('C', 'whole'), ('D', 'eighth'), ('B', 'whole'), ('E', 'half'), ('B', 'half'), ('A', 'eighth'), ('F', 'sixteenth'), ('D', 'whole'), ('D', 'half'), ('C', 'eighth'), ('C', 'whole'), ('A', 'half'), ('G', 'quarter'), ('B', 'sixteenth'), ('D', 'sixteenth'), ('F', 'eighth'), ('D', 'eighth'), ('C', 'whole'), ('B', 'eighth'), ('B', 'eighth'), ('E', 'half'), ('A', 'half'), ('D', 'eighth'), ('G', 'sixteenth'), ('C', 'whole'), ('G', 'eighth'), ('F', 'quarter'), ('E', 'sixteenth'), ('F', 'whole'), ('E', 'whole'), ('B', 'whole'), ('F', 'whole'), ('E', 'quarter'), ('F', 'whole'), ('A', 'whole'), ('A', 'whole'), ('D', 'whole'), ('E', 'eighth'), ('B', 'half'), ('C', 'sixteenth'), ('F', 'whole'), ('B', 'eighth'), ('A', 'sixteenth'), ('A', 'whole'), ('A', 'quarter'), ('C', 'eighth'), ('F', 'whole'), ('A', 'sixteenth'), ('C', 'sixteenth'), ('C', 'sixteenth'), ('G', 'eighth'), ('D', 'sixteenth'), ('E', 'whole'), ('F', 'half'), ('F', 'half'), ('D', 'eighth')]
# Generation 27
# Best fitness in this generation: 100
# Best melody: [('G', 'whole'), ('G', 'quarter'), ('F', 'whole'), ('F', 'quarter'), ('D', 'whole'), ('E', 'quarter'), ('B', 'eighth'), ('E', 'whole'), ('D', 'eighth'), ('F', 'whole'), ('A', 'eighth'), ('G', 'sixteenth'), ('E', 'whole'), ('A', 'half'), ('D', 'eighth'), ('F', 'eighth'), ('D', 'whole'), ('A', 'half'), ('E', 'sixteenth'), ('E', 'half'), ('C', 'quarter'), ('G', 'half'), ('C', 'whole'), ('B', 'sixteenth'), ('B', 'half'), ('D', 'half'), ('E', 'whole'), ('F', 'half'), ('D', 'sixteenth'), ('E', 'half'), ('B', 'eighth'), ('E', 'eighth'), ('D', 'sixteenth'), ('D', 'quarter'), ('F', 'sixteenth'), ('C', 'half'), ('B', 'sixteenth'), ('G', 'quarter'), ('C', 'eighth'), ('A', 'half'), ('B', 'quarter'), ('E', 'whole'), ('F', 'sixteenth'), ('B', 'whole'), ('G', 'whole'), ('E', 'whole'), ('C', 'eighth'), ('E', 'half'), ('D', 'whole'), ('G', 'whole'), ('F', 'sixteenth'), ('D', 'whole'), ('B', 'half'), ('B', 'sixteenth'), ('G', 'sixteenth'), ('A', 'half'), ('E', 'half'), ('D', 'quarter'), ('E', 'eighth'), ('C', 'half'), ('C', 'whole'), ('D', 'sixteenth'), ('B', 'eighth'), ('B', 'eighth'), ('E', 'half'), ('A', 'half'), ('D', 'eighth'), ('G', 'sixteenth'), ('C', 'whole'), ('G', 'eighth'), ('F', 'quarter'), ('E', 'sixteenth'), ('F', 'whole'), ('E', 'whole'), ('B', 'whole'), ('F', 'whole'), ('E', 'quarter'), ('F', 'whole'), ('A', 'whole'), ('A', 'whole'), ('D', 'whole'), ('E', 'eighth'), ('B', 'half'), ('C', 'sixteenth'), ('F', 'whole'), ('B', 'eighth'), ('A', 'sixteenth'), ('C', 'whole'), ('G', 'whole'), ('A', 'quarter'), ('E', 'quarter'), ('A', 'whole'), ('C', 'sixteenth'), ('C', 'whole'), ('G', 'eighth'), ('D', 'sixteenth'), ('E', 'whole'), ('F', 'half'), ('F', 'half'), ('A', 'whole')]
# Generation 28
# Best fitness in this generation: 100
# ...
# Generation 43
# Best fitness in this generation: 100
# Best melody: [('G', 'whole'), ('G', 'quarter'), ('F', 'whole'), ('F', 'quarter'), ('D', 'whole'), ('F', 'quarter'), ('B', 'half'), ('G', 'whole'), ('D', 'eighth'), ('F', 'whole'), ('A', 'sixteenth'), ('G', 'sixteenth'), ('E', 'whole'), ('A', 'half'), ('D', 'eighth'), ('F', 'eighth'), ('D', 'whole'), ('A', 'half'), ('E', 'sixteenth'), ('E', 'half'), ('A', 'quarter'), ('G', 'quarter'), ('C', 'whole'), ('B', 'sixteenth'), ('G', 'half'), ('D', 'half'), ('C', 'sixteenth'), ('F', 'whole'), ('A', 'half'), ('E', 'half'), ('B', 'eighth'), ('E', 'sixteenth'), ('D', 'sixteenth'), ('E', 'half'), ('B', 'eighth'), ('A', 'half'), ('D', 'quarter'), ('B', 'quarter'), ('C', 'eighth'), ('A', 'half'), ('B', 'quarter'), ('E', 'whole'), ('F', 'sixteenth'), ('B', 'whole'), ('A', 'eighth'), ('E', 'sixteenth'), ('A', 'quarter'), ('D', 'half'), ('D', 'whole'), ('F', 'half'), ('D', 'whole'), ('B', 'quarter'), ('E', 'whole'), ('A', 'whole'), ('F', 'eighth'), ('D', 'quarter'), ('G', 'quarter'), ('B', 'sixteenth'), ('B', 'eighth'), ('F', 'quarter'), ('F', 'whole'), ('E', 'eighth'), ('B', 'eighth'), ('B', 'eighth'), ('E', 'half'), ('A', 'half'), ('D', 'eighth'), ('G', 'sixteenth'), ('C', 'whole'), ('G', 'eighth'), ('F', 'quarter'), ('E', 'sixteenth'), ('F', 'whole'), ('E', 'whole'), ('B', 'whole'), ('F', 'whole'), ('E', 'quarter'), ('F', 'whole'), ('A', 'whole'), ('A', 'whole'), ('D', 'whole'), ('E', 'eighth'), ('B', 'half'), ('C', 'sixteenth'), ('F', 'whole'), ('B', 'eighth'), ('D', 'whole'), ('A', 'whole'), ('A', 'quarter'), ('C', 'eighth'), ('F', 'whole'), ('D', 'whole'), ('C', 'sixteenth'), ('C', 'whole'), ('G', 'eighth'), ('D', 'sixteenth'), ('E', 'whole'), ('G', 'sixteenth'), ('F', 'half'), ('D', 'eighth')]
# Generation 44
# Best fitness in this generation: 100
# Best melody: [('G', 'whole'), ('G', 'quarter'), ('F', 'whole'), ('F', 'quarter'), ('D', 'whole'), ('F', 'quarter'), ('B', 'eighth'), ('G', 'whole'), ('D', 'eighth'), ('F', 'whole'), ('A', 'sixteenth'), ('G', 'sixteenth'), ('E', 'whole'), ('A', 'half'), ('D', 'eighth'), ('F', 'eighth'), ('D', 'whole'), ('F', 'half'), ('E', 'sixteenth'), ('E', 'half'), ('A', 'quarter'), ('G', 'half'), ('C', 'whole'), ('B', 'sixteenth'), ('G', 'half'), ('D', 'half'), ('C', 'sixteenth'), ('F', 'whole'), ('A', 'half'), ('E', 'half'), ('B', 'eighth'), ('E', 'sixteenth'), ('D', 'sixteenth'), ('E', 'half'), ('B', 'eighth'), ('A', 'half'), ('D', 'quarter'), ('B', 'quarter'), ('C', 'eighth'), ('A', 'half'), ('B', 'quarter'), ('E', 'whole'), ('F', 'sixteenth'), ('B', 'whole'), ('C', 'whole'), ('E', 'whole'), ('C', 'eighth'), ('E', 'half'), ('D', 'whole'), ('G', 'whole'), ('F', 'sixteenth'), ('B', 'quarter'), ('E', 'whole'), ('A', 'whole'), ('F', 'eighth'), ('D', 'quarter'), ('E', 'half'), ('D', 'quarter'), ('E', 'eighth'), ('C', 'half'), ('C', 'whole'), ('D', 'sixteenth'), ('B', 'eighth'), ('B', 'eighth'), ('E', 'half'), ('A', 'half'), ('D', 'eighth'), ('G', 'sixteenth'), ('C', 'whole'), ('G', 'eighth'), ('F', 'quarter'), ('E', 'sixteenth'), ('A', 'sixteenth'), ('C', 'half'), ('G', 'quarter'), ('C', 'whole'), ('D', 'half'), ('D', 'whole'), ('B', 'whole'), ('A', 'eighth'), ('G', 'eighth'), ('E', 'sixteenth'), ('B', 'whole'), ('C', 'sixteenth'), ('F', 'whole'), ('B', 'eighth'), ('A', 'sixteenth'), ('C', 'whole'), ('G', 'whole'), ('A', 'quarter'), ('E', 'quarter'), ('A', 'whole'), ('G', 'half'), ('D', 'eighth'), ('G', 'whole'), ('D', 'half'), ('E', 'half'), ('G', 'sixteenth'), ('C', 'sixteenth'), ('E', 'sixteenth')]
# Generation 45
# Best fitness in this generation: 100
# Best melody: [('G', 'whole'), ('G', 'quarter'), ('F', 'whole'), ('F', 'quarter'), ('D', 'whole'), ('F', 'quarter'), ('B', 'eighth'), ('G', 'whole'), ('D', 'eighth'), ('F', 'whole'), ('A', 'sixteenth'), ('G', 'sixteenth'), ('E', 'whole'), ('A', 'half'), ('D', 'sixteenth'), ('F', 'eighth'), ('D', 'whole'), ('A', 'half'), ('E', 'sixteenth'), ('E', 'half'), ('A', 'quarter'), ('G', 'half'), ('C', 'whole'), ('B', 'sixteenth'), ('G', 'half'), ('D', 'half'), ('C', 'sixteenth'), ('F', 'whole'), ('A', 'half'), ('E', 'half'), ('B', 'eighth'), ('E', 'sixteenth'), ('D', 'sixteenth'), ('E', 'half'), ('B', 'eighth'), ('A', 'half'), ('D', 'quarter'), ('B', 'quarter'), ('C', 'eighth'), ('A', 'half'), ('B', 'quarter'), ('E', 'whole'), ('F', 'sixteenth'), ('B', 'whole'), ('A', 'eighth'), ('E', 'sixteenth'), ('A', 'quarter'), ('E', 'sixteenth'), ('B', 'half'), ('A', 'eighth'), ('F', 'sixteenth'), ('D', 'whole'), ('B', 'half'), ('B', 'sixteenth'), ('G', 'sixteenth'), ('A', 'half'), ('E', 'half'), ('D', 'quarter'), ('E', 'eighth'), ('C', 'half'), ('C', 'whole'), ('D', 'sixteenth'), ('B', 'eighth'), ('B', 'half'), ('B', 'sixteenth'), ('C', 'whole'), ('B', 'whole'), ('G', 'quarter'), ('D', 'eighth'), ('A', 'sixteenth'), ('B', 'eighth'), ('B', 'whole'), ('C', 'quarter'), ('E', 'whole'), ('B', 'whole'), ('C', 'whole'), ('D', 'half'), ('D', 'whole'), ('B', 'whole'), ('A', 'eighth'), ('G', 'eighth'), ('E', 'sixteenth'), ('B', 'whole'), ('C', 'quarter'), ('B', 'sixteenth'), ('B', 'eighth'), ('D', 'whole'), ('A', 'whole'), ('A', 'quarter'), ('C', 'eighth'), ('F', 'whole'), ('A', 'whole'), ('C', 'sixteenth'), ('C', 'whole'), ('G', 'eighth'), ('D', 'sixteenth'), ('E', 'whole'), ('G', 'sixteenth'), ('F', 'half'), ('F', 'eighth')]
# Generation 46
# Best fitness in this generation: 100
# Best melody: [('G', 'whole'), ('G', 'quarter'), ('F', 'whole'), ('F', 'quarter'), ('D', 'whole'), ('F', 'quarter'), ('B', 'eighth'), ('G', 'whole'), ('D', 'eighth'), ('F', 'whole'), ('A', 'sixteenth'), ('G', 'sixteenth'), ('E', 'whole'), ('A', 'half'), ('D', 'sixteenth'), ('F', 'eighth'), ('D', 'whole'), ('A', 'half'), ('E', 'sixteenth'), ('E', 'half'), ('A', 'quarter'), ('G', 'half'), ('C', 'whole'), ('B', 'sixteenth'), ('G', 'half'), ('D', 'half'), ('C', 'sixteenth'), ('F', 'whole'), ('A', 'half'), ('E', 'half'), ('B', 'eighth'), ('E', 'sixteenth'), ('D', 'sixteenth'), ('E', 'half'), ('B', 'eighth'), ('C', 'half'), ('B', 'sixteenth'), ('G', 'quarter'), ('C', 'eighth'), ('A', 'half'), ('B', 'quarter'), ('E', 'whole'), ('F', 'sixteenth'), ('B', 'whole'), ('A', 'whole'), ('E', 'whole'), ('C', 'eighth'), ('E', 'half'), ('D', 'whole'), ('G', 'whole'), ('D', 'whole'), ('B', 'quarter'), ('E', 'whole'), ('A', 'whole'), ('F', 'eighth'), ('D', 'quarter'), ('G', 'quarter'), ('B', 'sixteenth'), ('E', 'eighth'), ('C', 'half'), ('C', 'whole'), ('D', 'sixteenth'), ('B', 'eighth'), ('B', 'eighth'), ('E', 'half'), ('A', 'half'), ('D', 'eighth'), ('G', 'sixteenth'), ('C', 'whole'), ('G', 'eighth'), ('F', 'quarter'), ('E', 'sixteenth'), ('A', 'sixteenth'), ('C', 'half'), ('G', 'quarter'), ('C', 'whole'), ('D', 'half'), ('D', 'whole'), ('B', 'whole'), ('A', 'eighth'), ('G', 'eighth'), ('E', 'sixteenth'), ('B', 'whole'), ('C', 'sixteenth'), ('F', 'whole'), ('B', 'eighth'), ('A', 'sixteenth'), ('A', 'whole'), ('A', 'quarter'), ('C', 'eighth'), ('F', 'whole'), ('A', 'whole'), ('C', 'sixteenth'), ('C', 'whole'), ('G', 'eighth'), ('D', 'sixteenth'), ('E', 'whole'), ('G', 'sixteenth'), ('F', 'half'), ('F', 'eighth')]
# Generation 47
# Best fitness in this generation: 100
# Best melody: [('G', 'whole'), ('G', 'quarter'), ('F', 'whole'), ('F', 'quarter'), ('D', 'whole'), ('F', 'quarter'), ('B', 'half'), ('G', 'whole'), ('D', 'eighth'), ('F', 'whole'), ('A', 'sixteenth'), ('G', 'sixteenth'), ('E', 'whole'), ('A', 'half'), ('D', 'eighth'), ('F', 'eighth'), ('D', 'whole'), ('A', 'half'), ('E', 'sixteenth'), ('E', 'half'), ('A', 'quarter'), ('G', 'quarter'), ('C', 'whole'), ('B', 'sixteenth'), ('G', 'half'), ('D', 'half'), ('C', 'sixteenth'), ('F', 'whole'), ('A', 'half'), ('E', 'whole'), ('B', 'eighth'), ('E', 'sixteenth'), ('D', 'sixteenth'), ('E', 'half'), ('B', 'eighth'), ('A', 'half'), ('D', 'quarter'), ('B', 'quarter'), ('C', 'eighth'), ('A', 'half'), ('B', 'quarter'), ('E', 'whole'), ('F', 'sixteenth'), ('B', 'whole'), ('A', 'eighth'), ('E', 'sixteenth'), ('A', 'quarter'), ('E', 'sixteenth'), ('B', 'half'), ('A', 'eighth'), ('F', 'sixteenth'), ('D', 'whole'), ('B', 'half'), ('B', 'sixteenth'), ('G', 'sixteenth'), ('A', 'half'), ('E', 'half'), ('D', 'quarter'), ('E', 'eighth'), ('C', 'half'), ('C', 'whole'), ('D', 'sixteenth'), ('B', 'eighth'), ('B', 'half'), ('B', 'sixteenth'), ('C', 'whole'), ('B', 'whole'), ('G', 'quarter'), ('D', 'eighth'), ('A', 'sixteenth'), ('B', 'eighth'), ('B', 'whole'), ('C', 'quarter'), ('E', 'whole'), ('B', 'whole'), ('C', 'whole'), ('D', 'half'), ('D', 'whole'), ('B', 'whole'), ('A', 'eighth'), ('G', 'eighth'), ('E', 'sixteenth'), ('B', 'whole'), ('C', 'quarter'), ('B', 'sixteenth'), ('B', 'eighth'), ('D', 'whole'), ('A', 'whole'), ('A', 'quarter'), ('C', 'eighth'), ('F', 'whole'), ('A', 'whole'), ('C', 'sixteenth'), ('C', 'whole'), ('G', 'eighth'), ('D', 'sixteenth'), ('E', 'whole'), ('G', 'sixteenth'), ('F', 'half'), ('F', 'eighth')]
# Generation 48
# Best fitness in this generation: 100
# Best melody: [('G', 'whole'), ('G', 'quarter'), ('F', 'whole'), ('F', 'quarter'), ('D', 'whole'), ('F', 'quarter'), ('B', 'half'), ('G', 'whole'), ('D', 'eighth'), ('F', 'whole'), ('A', 'sixteenth'), ('G', 'sixteenth'), ('E', 'whole'), ('A', 'half'), ('D', 'eighth'), ('F', 'eighth'), ('D', 'whole'), ('A', 'half'), ('E', 'sixteenth'), ('E', 'half'), ('A', 'quarter'), ('G', 'quarter'), ('C', 'whole'), ('B', 'sixteenth'), ('G', 'half'), ('D', 'half'), ('C', 'sixteenth'), ('F', 'whole'), ('A', 'half'), ('E', 'half'), ('B', 'eighth'), ('E', 'sixteenth'), ('D', 'sixteenth'), ('E', 'half'), ('B', 'eighth'), ('A', 'half'), ('D', 'quarter'), ('B', 'quarter'), ('C', 'eighth'), ('A', 'half'), ('B', 'quarter'), ('E', 'whole'), ('F', 'sixteenth'), ('B', 'whole'), ('A', 'eighth'), ('E', 'sixteenth'), ('A', 'quarter'), ('E', 'sixteenth'), ('D', 'whole'), ('G', 'whole'), ('F', 'sixteenth'), ('B', 'quarter'), ('E', 'whole'), ('A', 'whole'), ('F', 'eighth'), ('D', 'quarter'), ('E', 'half'), ('D', 'quarter'), ('E', 'eighth'), ('C', 'half'), ('E', 'whole'), ('B', 'sixteenth'), ('A', 'half'), ('B', 'half'), ('B', 'sixteenth'), ('A', 'half'), ('D', 'eighth'), ('G', 'sixteenth'), ('C', 'whole'), ('G', 'eighth'), ('F', 'quarter'), ('E', 'sixteenth'), ('F', 'whole'), ('E', 'whole'), ('B', 'whole'), ('F', 'whole'), ('D', 'half'), ('D', 'whole'), ('A', 'whole'), ('A', 'whole'), ('D', 'whole'), ('E', 'eighth'), ('D', 'half'), ('C', 'sixteenth'), ('F', 'whole'), ('B', 'eighth'), ('D', 'whole'), ('A', 'whole'), ('A', 'quarter'), ('C', 'eighth'), ('F', 'whole'), ('A', 'whole'), ('C', 'sixteenth'), ('C', 'whole'), ('G', 'eighth'), ('D', 'sixteenth'), ('E', 'whole'), ('G', 'sixteenth'), ('F', 'half'), ('F', 'eighth')]
# Generation 49
# Best fitness in this generation: 100
# Best melody: [('G', 'whole'), ('G', 'quarter'), ('F', 'whole'), ('F', 'quarter'), ('D', 'whole'), ('F', 'quarter'), ('C', 'eighth'), ('G', 'whole'), ('D', 'eighth'), ('F', 'whole'), ('A', 'sixteenth'), ('G', 'sixteenth'), ('E', 'whole'), ('A', 'half'), ('D', 'eighth'), ('F', 'eighth'), ('D', 'whole'), ('A', 'half'), ('E', 'sixteenth'), ('E', 'half'), ('A', 'quarter'), ('G', 'quarter'), ('C', 'whole'), ('B', 'sixteenth'), ('G', 'half'), ('D', 'half'), ('C', 'sixteenth'), ('F', 'whole'), ('A', 'half'), ('E', 'half'), ('B', 'eighth'), ('E', 'sixteenth'), ('D', 'sixteenth'), ('E', 'half'), ('B', 'eighth'), ('A', 'half'), ('D', 'quarter'), ('B', 'quarter'), ('C', 'eighth'), ('A', 'half'), ('B', 'quarter'), ('E', 'whole'), ('F', 'sixteenth'), ('B', 'whole'), ('G', 'whole'), ('E', 'whole'), ('C', 'eighth'), ('E', 'half'), ('D', 'whole'), ('G', 'whole'), ('D', 'whole'), ('B', 'quarter'), ('E', 'whole'), ('A', 'whole'), ('F', 'eighth'), ('D', 'quarter'), ('G', 'quarter'), ('B', 'sixteenth'), ('E', 'eighth'), ('C', 'half'), ('C', 'whole'), ('D', 'sixteenth'), ('B', 'eighth'), ('B', 'eighth'), ('E', 'half'), ('A', 'half'), ('D', 'eighth'), ('D', 'eighth'), ('B', 'half'), ('B', 'eighth'), ('B', 'whole'), ('F', 'quarter'), ('C', 'quarter'), ('E', 'whole'), ('B', 'whole'), ('F', 'whole'), ('E', 'quarter'), ('F', 'whole'), ('B', 'whole'), ('A', 'whole'), ('D', 'whole'), ('E', 'sixteenth'), ('G', 'half'), ('C', 'sixteenth'), ('F', 'whole'), ('B', 'eighth'), ('A', 'sixteenth'), ('C', 'whole'), ('G', 'whole'), ('A', 'quarter'), ('E', 'quarter'), ('A', 'whole'), ('C', 'sixteenth'), ('C', 'whole'), ('G', 'eighth'), ('D', 'sixteenth'), ('E', 'whole'), ('F', 'half'), ('F', 'half'), ('A', 'whole')]
# Generation 50
# Best fitness in this generation: 100
# Best melody: [('G', 'whole'), ('G', 'quarter'), ('F', 'whole'), ('F', 'quarter'), ('D', 'whole'), ('F', 'quarter'), ('C', 'eighth'), ('G', 'whole'), ('D', 'eighth'), ('F', 'whole'), ('A', 'sixteenth'), ('G', 'sixteenth'), ('E', 'whole'), ('A', 'half'), ('D', 'eighth'), ('F', 'eighth'), ('D', 'whole'), ('A', 'half'), ('E', 'sixteenth'), ('E', 'half'), ('A', 'quarter'), ('G', 'quarter'), ('C', 'whole'), ('B', 'sixteenth'), ('G', 'half'), ('D', 'half'), ('C', 'sixteenth'), ('F', 'whole'), ('A', 'half'), ('E', 'half'), ('B', 'eighth'), ('E', 'sixteenth'), ('D', 'sixteenth'), ('E', 'half'), ('B', 'eighth'), ('A', 'half'), ('D', 'quarter'), ('B', 'quarter'), ('C', 'eighth'), ('A', 'half'), ('B', 'quarter'), ('E', 'whole'), ('F', 'sixteenth'), ('B', 'whole'), ('A', 'eighth'), ('E', 'whole'), ('C', 'eighth'), ('E', 'half'), ('D', 'whole'), ('G', 'whole'), ('F', 'sixteenth'), ('B', 'quarter'), ('E', 'whole'), ('A', 'whole'), ('F', 'eighth'), ('D', 'quarter'), ('E', 'half'), ('D', 'quarter'), ('E', 'eighth'), ('C', 'half'), ('C', 'whole'), ('D', 'sixteenth'), ('B', 'eighth'), ('B', 'eighth'), ('E', 'half'), ('A', 'half'), ('D', 'eighth'), ('G', 'sixteenth'), ('C', 'whole'), ('G', 'eighth'), ('B', 'eighth'), ('B', 'whole'), ('C', 'quarter'), ('E', 'whole'), ('B', 'whole'), ('F', 'whole'), ('E', 'quarter'), ('F', 'whole'), ('A', 'whole'), ('A', 'whole'), ('D', 'whole'), ('E', 'eighth'), ('B', 'half'), ('C', 'sixteenth'), ('B', 'sixteenth'), ('B', 'eighth'), ('D', 'whole'), ('A', 'whole'), ('A', 'quarter'), ('D', 'eighth'), ('F', 'whole'), ('D', 'whole'), ('C', 'sixteenth'), ('C', 'whole'), ('G', 'eighth'), ('D', 'sixteenth'), ('E', 'whole'), ('G', 'sixteenth'), ('F', 'half'), ('A', 'whole')]
# Best melody after evolution: [('G', 'whole'), ('G', 'quarter'), ('F', 'whole'), ('F', 'quarter'), ('D', 'whole'), ('F', 'quarter'), ('C', 'eighth'), ('G', 'whole'), ('D', 'eighth'), ('F', 'whole'), ('A', 'sixteenth'), ('G', 'sixteenth'), ('E', 'whole'), ('A', 'half'), ('D', 'eighth'), ('F', 'eighth'), ('D', 'whole'), ('A', 'half'), ('E', 'sixteenth'), ('E', 'half'), ('A', 'quarter'), ('G', 'quarter'), ('C', 'whole'), ('B', 'sixteenth'), ('G', 'half'), ('D', 'half'), ('C', 'sixteenth'), ('F', 'whole'), ('A', 'half'), ('E', 'half'), ('B', 'eighth'), ('E', 'sixteenth'), ('D', 'sixteenth'), ('E', 'half'), ('B', 'eighth'), ('A', 'half'), ('D', 'quarter'), ('B', 'quarter'), ('C', 'eighth'), ('A', 'half'), ('B', 'quarter'), ('E', 'whole'), ('F', 'sixteenth'), ('B', 'whole'), ('A', 'eighth'), ('E', 'whole'), ('C', 'eighth'), ('E', 'half'), ('D', 'whole'), ('G', 'whole'), ('F', 'sixteenth'), ('B', 'quarter'), ('E', 'whole'), ('A', 'whole'), ('F', 'eighth'), ('D', 'quarter'), ('E', 'half'), ('D', 'quarter'), ('E', 'eighth'), ('C', 'half'), ('C', 'whole'), ('D', 'sixteenth'), ('B', 'eighth'), ('B', 'eighth'), ('E', 'half'), ('A', 'half'), ('D', 'eighth'), ('G', 'sixteenth'), ('C', 'whole'), ('G', 'eighth'), ('B', 'eighth'), ('B', 'whole'), ('C', 'quarter'), ('E', 'whole'), ('B', 'whole'), ('F', 'whole'), ('E', 'quarter'), ('F', 'whole'), ('A', 'whole'), ('A', 'whole'), ('D', 'whole'), ('E', 'eighth'), ('B', 'half'), ('C', 'sixteenth'), ('B', 'sixteenth'), ('B', 'eighth'), ('D', 'whole'), ('A', 'whole'), ('A', 'quarter'), ('D', 'eighth'), ('F', 'whole'), ('D', 'whole'), ('C', 'sixteenth'), ('C', 'whole'), ('G', 'eighth'), ('D', 'sixteenth'), ('E', 'whole'), ('G', 'sixteenth'), ('F', 'half'), ('A', 'whole')]

# %%
import mido
from mido import MidiFile, MidiTrack, Message

# Map note names to MIDI numbers (C major scale for simplicity)
note_mapping = {
    'C': 60,  # Middle C
    'C#': 61, 
    'D': 62,
    'D#': 63,
    'E': 64,
    'F': 65,
    'F#': 66,
    'G': 67,
    'G#': 68,
    'A': 69,
    'A#': 70,
    'B': 71
}

# Rhythm durations in MIDI ticks
rhythm_durations = {
    'whole': 1920,    # 4 beats
    'half': 960,      # 2 beats
    'quarter': 480,   # 1 beat
    'eighth': 240,    # 0.5 beats
    'sixteenth': 120  # 0.25 beats
}

def create_midi(melody, filename):
    # Create a new midi file
    midi = MidiFile()
    track = MidiTrack()
    midi.tracks.append(track)

    # Add track name
    track.append(mido.MetaMessage('track_name', name='Melody'))

    # Set tempo (500000 microseconds per beat, which equals 120 BPM)
    track.append(mido.MetaMessage('set_tempo', tempo=500000))

    # Start time (initially set to 0)
    time = 0

    # Create the melody notes
    for note, rhythm in melody:
        # Convert note to MIDI number
        note_number = note_mapping[note]

        # Get the duration in ticks from the rhythm
        duration = rhythm_durations[rhythm]

        # Add a note_on message
        track.append(Message('note_on', note=note_number, velocity=64, time=time))

        # Add a note_off message after the note duration
        track.append(Message('note_off', note=note_number, velocity=64, time=duration))

        # Set time to zero for the next note to start immediately after the previous
        time = 0

    # Save the midi file to disk
    midi.save(filename)

# Example melody (the sequence you provided)
melody = [
    ('G', 'whole'), ('F', 'quarter'), ('G', 'sixteenth'), ('G', 'sixteenth'), 
    ('E', 'whole'), ('G', 'quarter'), ('E', 'eighth'), ('F', 'eighth'), 
    ('C', 'quarter'), ('F', 'sixteenth'), ('C', 'quarter'), ('E', 'quarter'), 
    ('F', 'sixteenth'), ('D', 'half'), ('G', 'eighth'), ('G', 'sixteenth')
    # Add more notes from your sequence here...
]

# Convert the melody to a MIDI file
create_midi(best_melody, 'ga_melody_complex.mid')

# %% [markdown]
# # Creating Music Sheet

# %%
import mido
from mido import MidiFile, MidiTrack, Message
from music21 import stream, note, metadata

# Map note names to MIDI numbers (C major scale for simplicity)
note_mapping = {
    'C': 60,  # Middle C
    'C#': 61, 
    'D': 62,
    'D#': 63,
    'E': 64,
    'F': 65,
    'F#': 66,
    'G': 67,
    'G#': 68,
    'A': 69,
    'A#': 70,
    'B': 71
}

# Rhythm durations in quarter notes (for music21)
rhythm_durations = {
    'whole': 4.0,    # 4 beats
    'half': 2.0,      # 2 beats
    'quarter': 1.0,   # 1 beat
    'eighth': 0.5,    # 0.5 beats
    'sixteenth': 0.25 # 0.25 beats
}

def create_music_sheet(melody):
    # Create a music21 Stream object (this will hold all the notes)
    melody_stream = stream.Stream()

    # Set metadata (optional)
    melody_stream.metadata = metadata.Metadata()
    melody_stream.metadata.title = "Generated Melody"
    melody_stream.metadata.composer = "AI Generated"

    # Add notes to the stream
    for note_name, rhythm in melody:
        # Convert note to music21 note object
        m21_note = note.Note(note_name, quarterLength=rhythm_durations[rhythm])
        melody_stream.append(m21_note)

    # Show the music sheet (it opens the music21 sheet view)
    # melody_stream.show()

    # Optionally, you can save the sheet music as a PDF or MusicXML
    # melody_stream.write('pdf', fp='generated_melody.pdf')  # Save as PDF
    melody_stream.write('musicxml', fp='generated_melody.xml')  # Save as MusicXML

# Example melody (the sequence you provided)
melody = [
    ('G', 'whole'), ('F', 'quarter'), ('G', 'sixteenth'), ('G', 'sixteenth'), 
    ('E', 'whole'), ('G', 'quarter'), ('E', 'eighth'), ('F', 'eighth'), 
    ('C', 'quarter'), ('F', 'sixteenth'), ('C', 'quarter'), ('E', 'quarter'), 
    ('F', 'sixteenth'), ('D', 'half'), ('G', 'eighth'), ('G', 'sixteenth')
    # Add more notes from your sequence here...
]

# Generate and display the music sheet
create_music_sheet(best_melody)

# %% [markdown]
# # Exporting to pdf

# %%
#https://github.com/musescore/MuseScore/releases
#MuseScore-Studio-4.4.3.242971445.dmg

# %%
import subprocess
import os

# Path to your MusicXML file
musicxml_path = "generated_melody.xml"
pdf_output_path = "generated_melody.pdf"

# Path to MuseScore executable (modify according to your system)
musescore_executable = "/Applications/MuseScore 4.app/Contents/MacOS/mscore"

# Run the MuseScore command to convert MusicXML to PDF
subprocess.run([musescore_executable, musicxml_path, "-o", pdf_output_path])

print(f"PDF file generated: {pdf_output_path}")
# Out:
# qt.qml.typeregistration: Invalid QML element name "IconCode"; value type names should begin with a lowercase letter
# qt.qml.typeregistration: Invalid QML element name "MusicalSymbolCodes"; value type names should begin with a lowercase letter
# qt.qml.typeregistration: Invalid QML element name "ContainerType"; value type names should begin with a lowercase letter
# qt.qml.typeregistration: Invalid QML element name "NavigationEvent"; value type names should begin with a lowercase letter
# qt.qml.typeregistration: Invalid QML element name "MUAccessible"; value type names should begin with a lowercase letter
# qt.qml.typeregistration: Invalid QML element name "CompareType"; value type names should begin with a lowercase letter
# qt.qml.typeregistration: Invalid QML element name "SelectionMode"; value type names should begin with a lowercase letter
# qt.qml.typeregistration: Invalid QML element name "ToolBarItemType"; value type names should begin with a lowercase letter
# qt.qml.typeregistration: Invalid QML element name "DockToolBarAlignment"; value type names should begin with a lowercase letter
# qt.qml.typeregistration: Invalid QML element name "Location"; value type names should begin with a lowercase letter
# qt.qml.typeregistration: Invalid QML element name "CloudVisibility"; value type names should begin with a lowercase letter
# qt.qml.typeregistration: Invalid QML element name "SaveToCloudResponse"; value type names should begin with a lowercase letter
# qt.qml.typeregistration: Invalid QML element name "DirectionTypes"; value type names should begin with a lowercase letter
# qt.qml.typeregistration: Invalid QML element name "SlurTieTypes"; value type names should begin with a lowercase letter
# qt.qml.typeregistration: Invalid QML element name "NoteHead"; value type names should begin with a lowercase letter
# qt.qml.typeregistration: Invalid QML element name "Beam"; value type names should begin with a lowercase letter
# qt.qml.typeregistration: Invalid QML element name "Hairpin"; value type names should begin with a lowercase letter
# qt.qml.typeregistration: Invalid QML element name "OrnamentTypes"; value type names should begin with a lowercase letter
# qt.qml.typeregistration: Invalid QML element name "Dynamic"; value type names should begin with a lowercase letter
# qt.qml.typeregistration: Invalid QML element name "Glissando"; value type names should begin with a lowercase letter
# qt.qml.typeregistration: Invalid QML element name "CommonTypes"; value type names should begin with a lowercase letter
# qt.qml.typeregistration: Invalid QML element name "BarlineTypes"; value type names should begin with a lowercase letter
# qt.qml.typeregistration: Invalid QML element name "MarkerTypes"; value type names should begin with a lowercase letter
# qt.qml.typeregistration: Invalid QML element name "KeySignatureTypes"; value type names should begin with a lowercase letter
# qt.qml.typeregistration: Invalid QML element name "AccidentalTypes"; value type names should begin with a lowercase letter
# qt.qml.typeregistration: Invalid QML element name "FretDiagramTypes"; value type names should begin with a lowercase letter
# qt.qml.typeregistration: Invalid QML element name "LineTypes"; value type names should begin with a lowercase letter
# qt.qml.typeregistration: Invalid QML element name "TextTypes"; value type names should begin with a lowercase letter
# qt.qml.typeregistration: Invalid QML element name "ArticulationTypes"; value type names should begin with a lowercase letter
# qt.qml.typeregistration: Invalid QML element name "AmbitusTypes"; value type names should begin with a lowercase letter
# qt.qml.typeregistration: Invalid QML element name "ChordSymbolTypes"; value type names should begin with a lowercase letter
# qt.qml.typeregistration: Invalid QML element name "BendTypes"; value type names should begin with a lowercase letter
# qt.qml.typeregistration: Invalid QML element name "TremoloBarTypes"; value type names should begin with a lowercase letter
# qt.qml.typeregistration: Invalid QML element name "TremoloTypes"; value type names should begin with a lowercase letter
# qt.qml.typeregistration: Invalid QML element name "VoiceTypes"; value type names should begin with a lowercase letter
# qt.qml.typeregistration: Invalid QML element name "InstrumentsTreeItemType"; value type names should begin with a lowercase letter
# qt.qml.typeregistration: Invalid QML element name "StandardButton"; value type names should begin with a lowercase letter
# qt.qml.typeregistration: Invalid QML element name "SaveLocationType"; value type names should begin with a lowercase letter
# qt.qml.typeregistration: Invalid QML element name "GenerateAudioTimePeriodType"; value type names should begin with a lowercase letter
# qt.qml.typeregistration: Invalid QML element name "MigrationType"; value type names should begin with a lowercase letter
# PDF file generated: generated_melody.pdf
