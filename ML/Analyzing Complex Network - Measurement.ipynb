# %%
##Code taken from NetworkX Documentation
##Compiled by jecs89

#Import lines
# %pylab inline
import networkx as nx

from matplotlib import pyplot as plt
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
prefix = './exp 1/'
neg = 'net_neg_'
pos = 'net_pos_'
pofix = '.net'

for i in range(1,6):
    G1=nx.read_pajek(prefix+neg+str(i)+pofix)
    G=nx.Graph(G1)
#     print(G.number_of_nodes())
#     print(G.number_of_edges())

    # print(nx.average_neighbor_degree(G))
    var = nx.average_neighbor_degree(G, weight='weight')
    mylist = []
    myval = []
    # print(var)
    for idx in var:
        mylist.append(int(idx))
        myval.append(var[idx])
    # print(mylist)
    # print(myval)
    
    ax = plt.subplot(3,2,i)
    ax.set_ylim((0, 8))
    plt.plot(mylist,myval)

#     print(nx.k_nearest_neighbors(G, weight='weight'))
    myval = []
    var = nx.k_nearest_neighbors(G, weight='weight')
    
    for idx in var:
        myval.append(var[idx])
    np.min(np.array(myval))
    print(np.min(np.array(myval)) + ' ' + np.max(np.array(myval)))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-72-2c2d370a3d99> in <module>
#      32         myval.append(var[idx])
#      33     np.min(np.array(myval))
# ---> 34     print(np.min(np.array(myval)) + ' ' + np.max(np.array(myval)))
#      35
#      36
#
# TypeError: ufunc 'add' did not contain a loop with signature matching types dtype('<U32') dtype('<U32') dtype('<U32')

# %%
prefix = './exp 1/'
neg = 'net_neg_'
pos = 'net_pos_'
pofix = '.net'

for i in range(1,6):
    G1=nx.read_pajek(prefix+pos+str(i)+pofix)
    G=nx.Graph(G1)

    var = nx.average_neighbor_degree(G, weight='weight')
    mylist = []
    myval = []

    for idx in var:
        mylist.append(int(idx))
        myval.append(var[idx])
    
    ax = plt.subplot(3,2,i)
    ax.set_ylim((0, 8))
    plt.plot(mylist,myval)
    
    print(nx.k_nearest_neighbors(G, weight='weight'))
# Out:
# {2: 4.0119507323568575, 1: 3.7867590103430993, 3: 3.76266343007267, 4: 3.7723054689282725, 5: 3.7286507484113414, 6: 3.623170256010183, 7: 3.8089069144747203, 8: 3.8253634612016114}
# {2: 5.056812115850962, 3: 4.904134496655224, 4: 4.5147941026944585, 6: 4.114649104647552, 1: 4.636897622781929, 5: 4.407922822232306, 8: 4.060502044593021, 7: 4.157487798199127}
# {3: 4.65104803677618, 2: 4.72080857771388, 4: 4.490276577355229, 1: 4.190792256385229, 5: 4.480092463433103, 7: 4.501562444515464, 6: 4.328111507207227, 8: 4.503461644973691}
# {3: 4.795639151182861, 1: 4.344158255409648, 5: 4.490395190263216, 2: 4.833338579207453, 7: 4.213467184392462, 4: 4.514344852165093, 6: 4.2882253598796, 8: 4.27124625548853}
# {3: 4.103272921286493, 2: 4.24115089277454, 5: 3.976127053315575, 1: 3.9861379923628184, 6: 3.826194520345617, 4: 3.898215892640557, 7: 4.065477698935631, 8: 3.761336227689339}

# %%
prefix = './exp 1/'
neg = 'net_neg_'
pos = 'net_pos_'
pofix = '.net'

for i in range(1,6):
    G1=nx.read_pajek(prefix+pos+str(i)+pofix)
    G=nx.Graph(G1)

    var = nx.average_neighbor_degree(G, source='in', target='in')
    mylist = []
    myval = []

    for idx in var:
        mylist.append(int(idx))
        myval.append(var[idx])

    ax = plt.subplot(3,2,i)
    ax.set_ylim((0, 8))
    plt.plot(mylist,myval)

# %%
prefix = './exp 1/'
neg = 'net_neg_'
pos = 'net_pos_'
pofix = '.net'

for i in range(1,6):
    G1=nx.read_pajek(prefix+pos+str(i)+pofix)
    G=nx.Graph(G1)

    var = nx.average_neighbor_degree(G, source='out', target='out')
    mylist = []
    myval = []

    for idx in var:
        mylist.append(int(idx))
        myval.append(var[idx])
    
    ax = plt.subplot(3,2,i)
    ax.set_ylim((0, 8))
    plt.plot(mylist,myval)

# %%
# print(nx.average_neighbor_degree(G, source='in', target='in'))
# print(nx.average_neighbor_degree(G, source='out', target='out'))

# print(nx.k_nearest_neighbors(G))
# print(nx.k_nearest_neighbors(G, weight='weight'))

# print(nx.average_clustering(G) )

# rc = nx.rich_club_coefficient(G, normalized=False)
# print(rc)

# r=nx.degree_assortativity_coefficient(G)
# print("%3.1f"%r)

# print( nx.betweenness_centrality(G) )

# c = nx.communicability(G)
# print(c)

# from networkx.algorithms.community import k_clique_communities
# c = list(k_clique_communities(G, 5))
# print(c)

# print(nx.laplacian_spectrum(G))

# print(nx.clustering(G,0))
# print(nx.clustering(G))

# r=nx.degree_pearson_correlation_coefficient(G)
# print("%3.1f"%r)
# Out:
# {3: 4.008190883190883, 2: 4.0503512880562065, 5: 3.9591397849462364, 1: 3.6770219603642205, 6: 3.8908629441624365, 4: 3.853161397670549, 7: 4.149416909620991, 8: 3.7976190476190474}
# {3: 4.103272921286493, 2: 4.24115089277454, 5: 3.976127053315575, 1: 3.9861379923628184, 6: 3.826194520345617, 4: 3.898215892640557, 7: 4.065477698935631, 8: 3.761336227689339}
