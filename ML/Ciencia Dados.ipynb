# %%
from IPython.display import display, HTML

display(HTML(data="""
<style>
    div#notebook-container    { width: 95%; }
    div#menubar-container     { width: 65%; }
    div#maintoolbar-container { width: 99%; }
</style>
"""))

import pandas as pd
df = pd.read_csv('house-prices-advanced-regression-techniques/train.csv')
df.head()
#pd.set_option('display.max_colwidth', 50)
# Out:
# <style>
#     div#notebook-container    { width: 95%; }
#     div#menubar-container     { width: 65%; }
#     div#maintoolbar-container { width: 99%; }
# </style>
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities    ...     PoolArea PoolQC Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 1         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 2         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 3         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 4         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
#
#   MoSold YrSold  SaleType  SaleCondition  SalePrice
# 0      2   2008        WD         Normal     208500
# 1      5   2007        WD         Normal     181500
# 2      9   2008        WD         Normal     223500
# 3      2   2006        WD        Abnorml     140000
# 4     12   2008        WD         Normal     250000
#
# [5 rows x 81 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
# Id               1460 non-null int64
# MSSubClass       1460 non-null int64
# MSZoning         1460 non-null object
# LotFrontage      1201 non-null float64
# LotArea          1460 non-null int64
# Street           1460 non-null object
# Alley            91 non-null object
# LotShape         1460 non-null object
# LandContour      1460 non-null object
# Utilities        1460 non-null object
# LotConfig        1460 non-null object
# LandSlope        1460 non-null object
# Neighborhood     1460 non-null object
# Condition1       1460 non-null object
# Condition2       1460 non-null object
# BldgType         1460 non-null object
# HouseStyle       1460 non-null object
# OverallQual      1460 non-null int64
# OverallCond      1460 non-null int64
# YearBuilt        1460 non-null int64
# YearRemodAdd     1460 non-null int64
# RoofStyle        1460 non-null object
# RoofMatl         1460 non-null object
# Exterior1st      1460 non-null object
# Exterior2nd      1460 non-null object
# MasVnrType       1452 non-null object
# MasVnrArea       1452 non-null float64
# ExterQual        1460 non-null object
# ExterCond        1460 non-null object
# Foundation       1460 non-null object
# BsmtQual         1423 non-null object
# BsmtCond         1423 non-null object
# BsmtExposure     1422 non-null object
# BsmtFinType1     1423 non-null object
# BsmtFinSF1       1460 non-null int64
# BsmtFinType2     1422 non-null object
# BsmtFinSF2       1460 non-null int64
# BsmtUnfSF        1460 non-null int64
# TotalBsmtSF      1460 non-null int64
# Heating          1460 non-null object
# HeatingQC        1460 non-null object
# CentralAir       1460 non-null object
# Electrical       1459 non-null object
# 1stFlrSF         1460 non-null int64
# 2ndFlrSF         1460 non-null int64
# LowQualFinSF     1460 non-null int64
# GrLivArea        1460 non-null int64
# BsmtFullBath     1460 non-null int64
# BsmtHalfBath     1460 non-null int64
# FullBath         1460 non-null int64
# HalfBath         1460 non-null int64
# BedroomAbvGr     1460 non-null int64
# KitchenAbvGr     1460 non-null int64
# KitchenQual      1460 non-null object
# TotRmsAbvGrd     1460 non-null int64
# Functional       1460 non-null object
# Fireplaces       1460 non-null int64
# FireplaceQu      770 non-null object
# GarageType       1379 non-null object
# GarageYrBlt      1379 non-null float64
# GarageFinish     1379 non-null object
# GarageCars       1460 non-null int64
# GarageArea       1460 non-null int64
# GarageQual       1379 non-null object
# GarageCond       1379 non-null object
# PavedDrive       1460 non-null object
# WoodDeckSF       1460 non-null int64
# OpenPorchSF      1460 non-null int64
# EnclosedPorch    1460 non-null int64
# 3SsnPorch        1460 non-null int64
# ScreenPorch      1460 non-null int64
# PoolArea         1460 non-null int64
# PoolQC           7 non-null object
# Fence            281 non-null object
# MiscFeature      54 non-null object
# MiscVal          1460 non-null int64
# MoSold           1460 non-null int64
# YrSold           1460 non-null int64
# SaleType         1460 non-null object
# SaleCondition    1460 non-null object
# SalePrice        1460 non-null int64
# dtypes: float64(3), int64(35), object(43)
# memory usage: 924.0+ KB

# %%
df.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726
# std       1.112799    30.202904     20.645407   181.066207   456.098091
# min       1.000000  1872.000000   1950.000000     0.000000     0.000000
# 25%       5.000000  1954.000000   1967.000000     0.000000     0.000000
# 50%       5.000000  1973.000000   1994.000000     0.000000   383.500000
# 75%       6.000000  2000.000000   2004.000000   166.000000   712.250000
# max       9.000000  2010.000000   2010.000000  1600.000000  5644.000000
#
#            ...         WoodDeckSF  OpenPorchSF  EnclosedPorch    3SsnPorch  \
# count      ...        1460.000000  1460.000000    1460.000000  1460.000000
# mean       ...          94.244521    46.660274      21.954110     3.409589
# std        ...         125.338794    66.256028      61.119149    29.317331
# min        ...           0.000000     0.000000       0.000000     0.000000
# 25%        ...           0.000000     0.000000       0.000000     0.000000
# 50%        ...           0.000000    25.000000       0.000000     0.000000
# 75%        ...         168.000000    68.000000       0.000000     0.000000
# max        ...         857.000000   547.000000     552.000000   508.000000
#
#        ScreenPorch     PoolArea       MiscVal       MoSold       YrSold  \
# count  1460.000000  1460.000000   1460.000000  1460.000000  1460.000000
# mean     15.060959     2.758904     43.489041     6.321918  2007.815753
# std      55.757415    40.177307    496.123024     2.703626     1.328095
# min       0.000000     0.000000      0.000000     1.000000  2006.000000
# 25%       0.000000     0.000000      0.000000     5.000000  2007.000000
# 50%       0.000000     0.000000      0.000000     6.000000  2008.000000
# 75%       0.000000     0.000000      0.000000     8.000000  2009.000000
# max     480.000000   738.000000  15500.000000    12.000000  2010.000000
#
#            SalePrice
# count    1460.000000
# mean   180921.195890
# std     79442.502883
# min     34900.000000
# 25%    129975.000000
# 50%    163000.000000
# 75%    214000.000000
# max    755000.000000
#
# [8 rows x 38 columns]

# %%
print(type(df))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
df.shape[0]
df['LotFrontage'][0]

mydf = df[['LotArea','Street','BldgType','HouseStyle','OverallQual', 'OverallCond','YearBuilt','TotalBsmtSF','BedroomAbvGr','KitchenAbvGr']]

# %%
count = 0

for i in range(0,df.shape[0]):
    count += df['MSSubClass'][i]
#print(count/df.shape[0])
print(mydf.mean())

mydf.info()
# Out:
# LotArea         10516.828082
# OverallQual         6.099315
# OverallCond         5.575342
# YearBuilt        1971.267808
# TotalBsmtSF      1057.429452
# BedroomAbvGr        2.866438
# KitchenAbvGr        1.046575
# dtype: float64
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 10 columns):
# LotArea         1460 non-null int64
# Street          1460 non-null object
# BldgType        1460 non-null object
# HouseStyle      1460 non-null object
# OverallQual     1460 non-null int64
# OverallCond     1460 non-null int64
# YearBuilt       1460 non-null int64
# TotalBsmtSF     1460 non-null int64
# BedroomAbvGr    1460 non-null int64
# KitchenAbvGr    1460 non-null int64
# dtypes: int64(7), object(3)
# memory usage: 114.1+ KB

# %%
print(mydf.median())
# Out:
# LotArea         9478.5
# OverallQual        6.0
# OverallCond        5.0
# YearBuilt       1973.0
# TotalBsmtSF      991.5
# BedroomAbvGr       3.0
# KitchenAbvGr       1.0
# dtype: float64

# %%
print(mydf.mode())
# Out:
#    LotArea Street BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# 0     7200   Pave     1Fam     1Story            5            5       2006
#
#    TotalBsmtSF  BedroomAbvGr  KitchenAbvGr
# 0            0             3             1

# %%
#print(mydf.BedroomAbvGr.quantile([0.25,0.5, 0.75]))
print(mydf.describe())
# Out:
#              LotArea  OverallQual  OverallCond    YearBuilt  TotalBsmtSF  \
# count    1460.000000  1460.000000  1460.000000  1460.000000  1460.000000
# mean    10516.828082     6.099315     5.575342  1971.267808  1057.429452
# std      9981.264932     1.382997     1.112799    30.202904   438.705324
# min      1300.000000     1.000000     1.000000  1872.000000     0.000000
# 25%      7553.500000     5.000000     5.000000  1954.000000   795.750000
# 50%      9478.500000     6.000000     5.000000  1973.000000   991.500000
# 75%     11601.500000     7.000000     6.000000  2000.000000  1298.250000
# max    215245.000000    10.000000     9.000000  2010.000000  6110.000000
#
#        BedroomAbvGr  KitchenAbvGr
# count   1460.000000   1460.000000
# mean       2.866438      1.046575
# std        0.815778      0.220338
# min        0.000000      0.000000
# 25%        2.000000      1.000000
# 50%        3.000000      1.000000
# 75%        3.000000      1.000000
# max        8.000000      3.000000

# %%
print(mydf.max())
# Out:
# LotArea         215245
# Street            Pave
# BldgType        TwnhsE
# HouseStyle        SLvl
# OverallQual         10
# OverallCond          9
# YearBuilt         2010
# TotalBsmtSF       6110
# BedroomAbvGr         8
# KitchenAbvGr         3
# dtype: object

# %%
print(mydf.min())
# Out:
# LotArea           1300
# Street            Grvl
# BldgType          1Fam
# HouseStyle      1.5Fin
# OverallQual          1
# OverallCond          1
# YearBuilt         1872
# TotalBsmtSF          0
# BedroomAbvGr         0
# KitchenAbvGr         0
# dtype: object

# %%
print(mydf.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 10 columns):
# LotArea         1460 non-null int64
# Street          1460 non-null object
# BldgType        1460 non-null object
# HouseStyle      1460 non-null object
# OverallQual     1460 non-null int64
# OverallCond     1460 non-null int64
# YearBuilt       1460 non-null int64
# TotalBsmtSF     1460 non-null int64
# BedroomAbvGr    1460 non-null int64
# KitchenAbvGr    1460 non-null int64
# dtypes: int64(7), object(3)
# memory usage: 114.1+ KB
# None

# %%
print(mydf.var())
# Out:
# LotArea         9.962565e+07
# OverallQual     1.912679e+00
# OverallCond     1.238322e+00
# YearBuilt       9.122154e+02
# TotalBsmtSF     1.924624e+05
# BedroomAbvGr    6.654938e-01
# KitchenAbvGr    4.854892e-02
# dtype: float64

# %%
print(mydf.std())
# Out:
# LotArea         9981.264932
# OverallQual        1.382997
# OverallCond        1.112799
# YearBuilt         30.202904
# TotalBsmtSF      438.705324
# BedroomAbvGr       0.815778
# KitchenAbvGr       0.220338
# dtype: float64

# %%
import numpy as np
import matplotlib.pyplot as plt

#x = mydf['BedroomAbvGr']
#y = df['SalePrice']

# count = 1
# fig = plt.figure(figsize = (10,10))
# for row in mydf:
#     for column in mydf:
#         plt.subplot(10,10,int(count))
#         #plt.title(column)
#         plt.scatter(mydf[row], mydf[column], s=1) 
#         count += 1
#         plt.subplots_adjust(hspace=0.5)
#         plt.grid(True)
#         plt.axis('off')
        
# fig.text(0.5, 0.04, 'common xlabel', ha='center', va='center')
# fig.text(0,0,'common ylabel', ha='center', va='center', rotation='vertical')
# plt.show()

# plt.ylabel('SalePrice', fontsize=13)
# plt.xlabel('GrLivArea', fontsize=13)

pd.plotting.scatter_matrix(mydf, alpha=0.2, figsize=(10, 10))
plt.axis('off')
plt.savefig('scatter.png')
plt.show()

# %%
print(mydf['Street'].value_counts())
print(mydf['BldgType'].value_counts())
print(mydf['HouseStyle'].value_counts())
cleanup_nums = {"Street": {"Grvl":0, "Pave":1},
                 "BldgType": {"1Fam":0, "TwnhsE": 1, "Duplex":2, "Twnhs":3, "2fmCon":4},
                 "HouseStyle": {"1Story":0, "2Story":2, "1.5Fin":3, "SLvl":4, "SFoyer":5, "1.5Unf":6, "2.5Unf":7, "2.5Fin":8}}
mydf.replace(cleanup_nums, inplace=True)
# Out:
# Pave    1454
# Grvl       6
# Name: Street, dtype: int64
# 1Fam      1220
# TwnhsE     114
# Duplex      52
# Twnhs       43
# 2fmCon      31
# Name: BldgType, dtype: int64
# 1Story    726
# 2Story    445
# 1.5Fin    154
# SLvl       65
# SFoyer     37
# 1.5Unf     14
# 2.5Unf     11
# 2.5Fin      8
# Name: HouseStyle, dtype: int64
# /home/jecs89/anaconda3/envs/tutorialConda/lib/python3.6/site-packages/pandas/core/generic.py:5821: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   regex=regex)

# %%
print(mydf['Street'].value_counts())
print(mydf['BldgType'].value_counts())
print(mydf['HouseStyle'].value_counts())
# Out:
# 1    1454
# 0       6
# Name: Street, dtype: int64
# 0    1220
# 1     114
# 2      52
# 3      43
# 4      31
# Name: BldgType, dtype: int64
# 0    726
# 2    445
# 3    154
# 4     65
# 5     37
# 6     14
# 7     11
# 8      8
# Name: HouseStyle, dtype: int64

# %%
#count, division = np.histogram(mydf['BedroomAbvGr'])
#plt.hist(count)

#count, division = np.histogram(mydf['Street'])
#plt.hist(count)

counter = 1
plt.figure(figsize = (7,7))
for column in mydf:
    plt.subplot(4,3,int(counter))
    plt.title(column)
    count, division = np.histogram(mydf[column])
    plt.subplots_adjust(hspace=0.5)
    plt.hist(count)
    counter += 1
plt.show()
plt.savefig('hist.png')

# %%
counter = 1
plt.figure(figsize = (7,7))
for column in mydf:
    plt.subplot(4,3,int(counter))
    plt.title(column)
    plt.subplots_adjust(hspace=0.5)
    mydf[column].value_counts().plot.bar()
    counter += 1
plt.show()

# %%
print(mydf['BedroomAbvGr'].value_counts())

counter = 1
plt.figure(figsize = (7,7))
for column in mydf:
    plt.subplot(4,3,int(counter))
    plt.title(column)
    plt.subplots_adjust(hspace=0.5)
    mydf.boxplot(column, grid=False)
    counter += 1
plt.show()
plt.savefig('boxplot.png')
# Out:
# 3    804
# 2    358
# 4    213
# 1     50
# 5     21
# 6      7
# 0      6
# 8      1
# Name: BedroomAbvGr, dtype: int64

# %%
import math
k    = round(math.sqrt(mydf.shape[0]))
cols = ['amplitud']
amplitud = pd.DataFrame(index = mydf.columns.values, columns =cols)
amplitud = amplitud.fillna(0)
for column in mydf:
    val_max = round(mydf[column].max())
    val_min = round(mydf[column].min())
    temp    = (val_max - val_min) / k
    amplitud.loc[column] = temp
print('xxx')
print(amplitud)
# Out:
# xxx
#                  amplitud
# LotArea       5630.131579
# Street           0.026316
# BldgType         0.105263
# HouseStyle       0.210526
# OverallQual      0.236842
# OverallCond      0.210526
# YearBuilt        3.631579
# TotalBsmtSF    160.789474
# BedroomAbvGr     0.210526
# KitchenAbvGr     0.078947

# %%
stats = np.zeros([3,10])
counter = 0
for column in mydf:
    stats[0,counter] = mydf[column].mean()
    stats[1,counter] = mydf[column].median()
    stats[2,counter] = mydf[column].mode()
    counter += 1
print(stats)
# Out:
# [[1.05168281e+04 9.95890411e-01 3.22602740e-01 1.38493151e+00
#   6.09931507e+00 5.57534247e+00 1.97126781e+03 1.05742945e+03
#   2.86643836e+00 1.04657534e+00]
#  [9.47850000e+03 1.00000000e+00 0.00000000e+00 2.00000000e+00
#   6.00000000e+00 5.00000000e+00 1.97300000e+03 9.91500000e+02
#   3.00000000e+00 1.00000000e+00]
#  [7.20000000e+03 1.00000000e+00 0.00000000e+00 0.00000000e+00
#   5.00000000e+00 5.00000000e+00 2.00600000e+03 0.00000000e+00
#   3.00000000e+00 1.00000000e+00]]
